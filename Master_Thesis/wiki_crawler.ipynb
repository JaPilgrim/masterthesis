# %%
import selenium
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

# %%
DRIVER_PATH = '/externals/'
next_page_class='/html/body/div[3]/div[3]/div[4]/span[2]/span[3]'
options = Options()
options.headless = True
options.add_argument("--window-size=1920,1200")
driver = webdriver.Chrome(options=options,executable_path=DRIVER_PATH)
driver.get('https://de.wikipedia.org/w/index.php?title=Spezial:Gesch%C3%BCtzte_Seiten&dir=prev&offset=37111&level=0&namespace=0&size=&size-mode=min&type=edit')
article_list=[]
while(1):
    title_list=driver.find_elements(By.CSS_SELECTOR,'td.TablePager_col_pr_page>a')
    for title in title_list:
        article_list.append(title.get_attribute('title'))
    try:
        next_click_element=driver.find_element(By.XPATH,next_page_class)
        next_click_element.click()
    except:
        break
    print(len(article_list))

driver.quit()
# Out:
# /var/folders/w8/40_qn26x4k134x3br37zmn5r0000gn/T/ipykernel_5798/413131530.py:4: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True
# /var/folders/w8/40_qn26x4k134x3br37zmn5r0000gn/T/ipykernel_5798/413131530.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options,executable_path=DRIVER_PATH)
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2842
# 2884
# 2926
# 2968
# 3010
# 3052
# 3094
# 3136
# 3178
# 3220
# 3262
# 3304
# 3346
# 3388
# 3430
# 3472
# 3514
# 3556
# 3598
# 3640
# ...

# %%
to_export=pd.Series(article_list)

# %%
to_export.to_csv('all_protected_wiki_list.csv')

# %%
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /opt/anaconda3/envs/sentence10/lib/python3.10/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File /opt/anaconda3/envs/sentence10/lib/python3.10/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File /opt/anaconda3/envs/sentence10/lib/python3.10/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
# ...
