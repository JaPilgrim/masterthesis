# %%
import seaborn as sns
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import statistics
import requests
import concurrent.futures
from collections import Counter

# %%
print(os.getcwd())
# Out:
# /root/projects/jpthesis/keygens/masterthesis/codebase

# %%
data/data_files/pipeline_steps/excellent_articles/1_all_articles_fetched.csv

# %%
def exploratory_stats(arrays, array_names):
    stats_list = []
    for idx, array in enumerate(arrays):
        array_name = array_names[idx]
        np_array = np.array(array, dtype=float)  # Ensure the array has a float dtype to handle NaNs

        mean = np.nanmean(np_array).round(2)
        median = np.nanmedian(np_array).round(2)
        min_value = np.nanmin(np_array).round(2)
        max_value = np.nanmax(np_array).round(2)
        std_dev = np.nanstd(np_array).round(2)
        q25 = np.nanpercentile(np_array, 25).round(2)
        q75 = np.nanpercentile(np_array, 75).round(2)

        stats_list.append([array_name, q25,mean,  q75, std_dev,  min_value,median, max_value])

    stats_df = pd.DataFrame(stats_list, columns=['Article Category','1st Quantile', 'Mean',  '3rd Quantile', 'Standard Deviation',  'Min','Median', 'Max'])
    
    return stats_df

# %% [markdown]
# ## Plotting on article level

# %%
excellent_art = pd.read_csv(f'data/data_files/pipeline_steps/excellent_articles/1_all_articles_fetched.csv')
readworthy_art = pd.read_csv(f'data/data_files/pipeline_steps/readworthy_articles/1_all_articles_fetched.csv')
protected_art = pd.read_csv(f'data/data_files/pipeline_steps/protected_articles/1_all_articles_fetched.csv')
max_len = max(len(excellent_art),len(readworthy_art),len(protected_art))
new_index = np.arange(max_len)

# excellent_art = excellent_art.reindex(new_index)
# protected_art = protected_art.reindex(new_index)

name_list = ['Protected Articles', 'Excellent Articles', 'Readworthy Articles']
category_name_list = ['Protected ', 'Excellent ', 'Readworthy']
char_count_article_df = pd.DataFrame()

# %% [markdown]
# ### Word Count

# %%
for i,length in enumerate(word_count_article_excellent):
    if length==1:
        print(excellent_art['title'].iloc[i])
# Out:
# Cheops
# Sesostris-I.-Pyramide
# Schlacht bei Tannenberg (1410)
# Schwabenkrieg
# Zweiter Italienisch-Libyscher Krieg
# Warschauer Aufstand
# Operation Phantom Fury
# Emil Zátopek
# Americium
# Argon
# Arsen
# Berkelium
# Blei
# Californium
# Caesium
# Curium
# Eisen
# Europium
# Gallium
# Helium
# Indium
# Krypton
# Lithium
# Lutetium
# Mangan
# Osmium
# Ruthenium
# Technetium
# Tellur
# Vanadium
# Xenon
# Ytterbium
# Zirconium
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
word_count_article_protected = np.array(protected_art['sub_texts'].apply(lambda x: len(str(x).split())))
word_count_article_excellent = np.array(excellent_art['sub_texts'].apply(lambda x: len(str(x).split())))
word_count_article_readworthy = np.array(readworthy_art['sub_texts'].apply(
    lambda x: len(str(x).split())))
word_count_article_protected = np.concatenate([word_count_article_protected , np.array([np.nan] * (
    max_len - len(word_count_article_protected)))])
word_count_article_excellent = np.concatenate([word_count_article_excellent , np.array([np.nan] * (
    max_len - len(word_count_article_excellent)))])
word_count_article_readworthy = np.concatenate([word_count_article_readworthy , np.array([np.nan] * (
    max_len - len(word_count_article_readworthy)))])

# %%
type(word_count_article_protected)
# Out:
# numpy.ndarray

# %%
type([np.nan] * (max_len - len(word_count_article_protected)))
# Out:
# list

# %%
ab.to_csv('stats_for_table_articlewordcount.csv',index=False)

# %%
ab=exploratory_stats(
    [word_count_article_protected, word_count_article_excellent, word_count_article_readworthy],
    category_name_list)
display(ab)
# Out:
#   Article Category  1st Quantile     Mean  3rd Quantile  Standard Deviation
# 0       Protected         318.00  2419.74       2997.00             3524.99  \
# 1       Excellent        2455.50  4946.90       6567.00             3765.82
# 2       Readworthy       1657.75  3480.13       4405.25             2987.06
#
#    Min  Median      Max
# 0  1.0  1058.0  33027.0
# 1  1.0  4136.0  48436.0
# 2  1.0  2683.5  33027.0

# %%
ax = sns.violinplot(data=[
    word_count_article_protected, word_count_article_excellent, word_count_article_readworthy
],
               inner='quartile')

# Set plot title and labels
plt.title('Word Count Distribution by Article Category')
plt.xlabel('Article Category')
plt.ylabel('Word Count')
plt.xticks([0, 1, 2], ['Protected ', 'Excellent ', 'Readworthy'])
ax.set_ylim(-1, 51000)
# Show the plot
plt.show()

# %%
ax = sns.violinplot(data=[word_count_article_protected, word_count_article_excellent, word_count_article_readworthy], inner='quartile')

# Set plot title and labels
plt.title('Word Count Distribution by Article Category')
plt.xlabel('Article Category')
plt.ylabel('Word Count')
plt.xticks([0, 1, 2], ['Protected ', 'Excellent ', 'Readworthy '])
ax.set_ylim(-1,6700)
# Show the plot
plt.show()

# %% [markdown]
# ### Character count

# %%
char_count_article_protected = protected_art['sub_texts'].apply(lambda x: len(str(x)))
char_count_article_excellent = excellent_art['sub_texts'].apply(lambda x: len(str(x)))
char_count_article_readworthy = readworthy_art['sub_texts'].apply(lambda x: len(str(x)))

# %%
char_count_article_protected = np.concatenate([
    char_count_article_protected,
    np.array([np.nan] * (max_len - len(char_count_article_protected)))
])
char_count_article_excellent = np.concatenate([
    char_count_article_excellent,
    np.array([np.nan] * (max_len - len(char_count_article_excellent)))
])
char_count_article_readworthy = np.concatenate([
    char_count_article_readworthy,
    np.array([np.nan] * (max_len - len(char_count_article_readworthy)))
])

# %%
ax = sns.violinplot(data=[
    char_count_article_protected, char_count_article_excellent, char_count_article_readworthy
],
                    inner='quartile')

# Set plot title and labels
plt.title('Character Count Distribution by Article Category')
plt.xlabel('Article Category')
plt.ylabel('Word Count')
plt.xticks([0, 1, 2], ['Protected ', 'Excellent ', 'Readworthy '])
ax.set_ylim(0, 380000)


# Show the plot
plt.show()

# %%
protected_charwords=np.nansum(char_count_article_protected)/np.nansum(word_count_article_protected)
excellent_charwords=np.nansum(char_count_article_excellent)/np.nansum(word_count_article_excellent)
readworthy_charwords=np.nansum(char_count_article_readworthy)/np.nansum(word_count_article_readworthy)

# %%
print(f"protected: {protected_charwords}, excellent: {excellent_charwords}, readworthy: {readworthy_charwords}")
# Out:
# protected: 7.499377993280236, excellent: 7.447989445864211, readworthy: 7.434205173304958

# %% [markdown]
# ### Topic Distribution

# %%
def get_article_categories(title, lang="de"):
    url = f"https://{lang}.wikipedia.org/w/api.php"

    params = {
        "action": "query",
        "format": "json",
        "titles": title,
        "prop": "categories",
        "cllimit": "max"
    }

    response = requests.get(url, params=params)
    data = response.json()

    # Extract the page from the query result
    page = list(data["query"]["pages"].values())[0]

    # Check if the page has categories
    if "categories" in page:
        categories = [
            cat["title"][10:] for cat in page["categories"] if cat["title"][0:9] == "Kategorie"
        ]
        return categories
    else:
        return None

# %%
import requests


def get_article_topic(title, lang="de"):

    def get_wikidata_id(title, lang="de"):
        url = "https://www.wikidata.org/w/api.php"
        params = {
            "action": "wbgetentities",
            "format": "json",
            "sites": f"{lang}wiki",
            "titles": title,
        }
        response = requests.get(url, params=params)
        data = response.json()

        if "entities" in data:
            entities = data["entities"]
            wikidata_id = None
            for entity in entities.values():
                if "id" in entity:
                    wikidata_id = entity["id"]
                    break
            return wikidata_id
        else:
            return None

    def get_label(wikidata_id, lang="de"):
        url = "https://www.wikidata.org/w/api.php"
        params = {
            "action": "wbgetentities",
            "format": "json",
            "ids": wikidata_id,
            "props": "labels",
            "languages": lang,
        }
        response = requests.get(url, params=params)
        data = response.json()

        label_data = data["entities"][wikidata_id]["labels"].get(lang)
        if label_data:
            return label_data["value"]
        else:
            return None

    def get_instance_or_subclass(wikidata_id, lang="de"):
        url = "https://www.wikidata.org/w/api.php"
        params = {
            "action": "wbgetentities",
            "format": "json",
            "ids": wikidata_id,
            "props": "claims",
            "languages": lang,
        }
        response = requests.get(url, params=params)
        data = response.json()

        instance_claims = data["entities"][wikidata_id]["claims"].get("P31", [])
        subclass_claims = data["entities"][wikidata_id]["claims"].get("P279", [])

        claims = instance_claims + subclass_claims
        if claims:
            claim_id = claims[0]["mainsnak"]["datavalue"]["value"]["id"]
            return get_label(claim_id, lang)
        else:
            return None

    wikidata_id = get_wikidata_id(title, lang)
    if wikidata_id:
        topic = get_instance_or_subclass(wikidata_id, lang)
        return topic
    else:
        return None


# Example usage
title = "Angela Merkel"
topic = get_article_topic(title)
print(f"Topic for '{title}':", topic)
# Out:
# Fetching topic for 'Angela Merkel'
# Topic for 'Angela Merkel': Mensch

# %%
excellent_titles = pd.read_csv(
    f'data/data_files/pipeline_steps/excellent_articles/0_excellent_titles.csv')
readworthy_titles = pd.read_csv(
    f'data/data_files/pipeline_steps/readworthy_articles/0_readworthy_titles.csv')
protected_titles = pd.read_csv(
    f'data/data_files/pipeline_steps/protected_articles/0_protected_titles.csv')

# %%
def get_category_topic_counter(title_list):
    category_list=[]
    topic_list=[]
    for title in title_list:
        curr_categories = get_article_categories(title)
        if curr_categories:
            category_list += curr_categories

        curr_topics = get_article_topic(title)
        
        topic_list.append(curr_topics)
    counted_categories = Counter(category_list)
    counted_topics = Counter(topic_list)


    # Convert the Counter object to a list of tuples (string, count)
    categories_result = list(counted_categories.items())
    topic_result = list(counted_topics.items())
    return categories_result, topic_result

# %%
import concurrent.futures
from collections import Counter

def process_title(title):
    categories = get_article_categories(title) or []
    topic = get_article_topic(title)
    return categories, topic

def get_category_topic_counter(title_list, max_workers=16):
    category_list = []
    topic_list = []

    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(process_title, title) for title in title_list]

        for future in concurrent.futures.as_completed(futures):
            try:
                categories, topic = future.result()
                category_list += categories
                topic_list.append(topic)
            except Exception as e:
                print(f"An error occurred: {e}")

    counted_categories = Counter(category_list)
    counted_topics = Counter(topic_list)

    # Convert the Counter object to a list of tuples (string, count)
    categories_result = list(counted_categories.items())
    topic_result = list(counted_topics.items())

    # Sort the results by counts in descending order
    categories_result.sort(key=lambda x: x[1], reverse=True)
    topic_result.sort(key=lambda x: x[1], reverse=True)

    return categories_result, topic_result


# Usage:
title_list = excellent_titles['title'].iloc[0:50]  # Your list of titles
categories_result, topic_result = get_category_topic_counter(title_list)
# Out:
# Fetching topic for 'Altausseer See'
# Fetching topic for 'Bäke (Telte)'
# Fetching topic for 'Amper'
# Fetching topic for 'Almsee'
# Fetching topic for 'Blabbergraben'
# Fetching topic for 'Bullengraben'
# Fetching topic for 'Elbe'
# Fetching topic for 'Dornbirner Ach'
# Fetching topic for 'Elsterwerda-Grödel-Floßkanal'
# Fetching topic for 'Europäisches Nordmeer'
# Fetching topic for 'Große Dhünntalsperre'
# Fetching topic for 'Grundlsee (See)'
# Fetching topic for 'Hochwasser in Würzburg'
# Fetching topic for 'Hochwasserrückhaltebecken Jonenbach'
# Fetching topic for 'Hochwasserschutz in Dresden'
# Fetching topic for 'Isar'
# Fetching topic for 'Ludwig-Donau-Main-Kanal'
# Fetching topic for 'Main'
# Fetching topic for 'Moälven'
# Fetching topic for 'Mono Lake'
# Fetching topic for 'Nationalpark Schleswig-Holsteinisches Wattenmeer'
# Fetching topic for 'Oderteich'
# Fetching topic for 'Osterseen'
# Fetching topic for 'Parsteiner See'
# Fetching topic for 'Pegel Würzburg'
# Fetching topic for 'Ragöse'
# Fetching topic for 'Schermützelsee'
# Fetching topic for 'Thermalbäder Baden'
# Fetching topic for 'Toplitzsee'
# Fetching topic for 'Walchensee'
# Fetching topic for 'Wedeler Au'
# Fetching topic for 'Weser'
# Fetching topic for 'Wiener Neustädter Kanal'
# Fetching topic for 'Wiese (Fluss)'
# Fetching topic for 'Babisnauer Pappel'
# Fetching topic for 'Belziger Landschaftswiesen'
# Fetching topic for 'Binghöhle'
# Fetching topic for 'Büyükkale'
# Fetching topic for 'Bryce-Canyon-Nationalpark'
# Fetching topic for 'Charlottenhöhle'
# Fetching topic for 'Dachsteingebirge'
# Fetching topic for 'Drei Zinnen'
# Fetching topic for 'Eberstadter Tropfsteinhöhle'
# Fetching topic for 'Eiger-Nordwand'
# Fetching topic for 'Externsteine'
# Fetching topic for 'Femeiche'
# Fetching topic for 'Glacier-Nationalpark (Vereinigte Staaten)'
# Fetching topic for 'Goetz-Höhle'
# Fetching topic for 'Grabeiche'
# Fetching topic for 'Große Nordwände der Alpen'

# %%
cats_exc,top_exc = get_category_topic_counter(excellent_titles['title'])
# Out:
# Fetching topic for 'Almsee'
# Fetching topic for 'Altausseer See'
# Fetching topic for 'Amper'
# Fetching topic for 'Blabbergraben'
# Fetching topic for 'Bäke (Telte)'
# Fetching topic for 'Bullengraben'
# Fetching topic for 'Dornbirner Ach'
# Fetching topic for 'Elbe'
# Fetching topic for 'Elsterwerda-Grödel-Floßkanal'
# Fetching topic for 'Europäisches Nordmeer'
# Fetching topic for 'Grundlsee (See)'
# Fetching topic for 'Große Dhünntalsperre'
# Fetching topic for 'Hochwasser in Würzburg'
# Fetching topic for 'Hochwasserrückhaltebecken Jonenbach'
# Fetching topic for 'Hochwasserschutz in Dresden'
# Fetching topic for 'Isar'
# Fetching topic for 'Main'
# Fetching topic for 'Ludwig-Donau-Main-Kanal'
# Fetching topic for 'Moälven'
# Fetching topic for 'Mono Lake'
# Fetching topic for 'Nationalpark Schleswig-Holsteinisches Wattenmeer'
# Fetching topic for 'Oderteich'
# Fetching topic for 'Osterseen'
# Fetching topic for 'Parsteiner See'
# Fetching topic for 'Pegel Würzburg'
# Fetching topic for 'Ragöse'
# Fetching topic for 'Schermützelsee'
# Fetching topic for 'Thermalbäder Baden'
# Fetching topic for 'Toplitzsee'
# Fetching topic for 'Walchensee'
# Fetching topic for 'Wedeler Au'
# Fetching topic for 'Weser'
# Fetching topic for 'Wiener Neustädter Kanal'
# Fetching topic for 'Wiese (Fluss)'
# Fetching topic for 'Babisnauer Pappel'
# Fetching topic for 'Belziger Landschaftswiesen'
# Fetching topic for 'Binghöhle'
# Fetching topic for 'Charlottenhöhle'
# Fetching topic for 'Bryce-Canyon-Nationalpark'
# Fetching topic for 'Büyükkale'
# Fetching topic for 'Dachsteingebirge'
# Fetching topic for 'Drei Zinnen'
# Fetching topic for 'Eiger-Nordwand'
# Fetching topic for 'Eberstadter Tropfsteinhöhle'
# Fetching topic for 'Externsteine'
# Fetching topic for 'Femeiche'
# Fetching topic for 'Glacier-Nationalpark (Vereinigte Staaten)'
# Fetching topic for 'Goetz-Höhle'
# Fetching topic for 'Grabeiche'
# Fetching topic for 'Große Nordwände der Alpen'
# Fetching topic for 'Großglockner'
# Fetching topic for 'Hesselberg'
# Fetching topic for 'Hoflößnitz'
# Fetching topic for 'Hohentwiel'
# Fetching topic for 'Höllengebirge'
# Fetching topic for 'Johannisberg (Jena-Lobeda)'
# Fetching topic for 'Kaditzer Linde'
# Fetching topic for 'Kaiserwald (Steiermark)'
# Fetching topic for 'Kasberger Linde'
# Fetching topic for 'Kittelsthaler Tropfsteinhöhle'
# Fetching topic for 'Königseiche'
# Fetching topic for 'König-Ludwig-Eiche'
# Fetching topic for 'König-Otto-Tropfsteinhöhle'
# Fetching topic for 'Kordigast'
# Fetching topic for 'Ku-ring-gai-Chase-Nationalpark'
# Fetching topic for 'Linde in Schenklengsfeld'
# Fetching topic for 'Lötschental'
# Fetching topic for 'Mount Everest'
# Fetching topic for 'Marienglashöhle'
# Fetching topic for 'Adelsgesellschaft'
# Fetching topic for 'Angkor'
# Fetching topic for 'Wenzel von Böhmen'
# Fetching topic for 'Agnes Bernauer'
# Fetching topic for 'Arnolf von Kärnten'
# Fetching topic for 'Burggrafschaft Friedberg'
# Fetching topic for 'Deutscher Orden'
# Fetching topic for 'Francesco Datini'
# Fetching topic for 'Friedrich I. (HRR)'
# Fetching topic for 'Friedrich II. (HRR)'
# Fetching topic for 'Friedrich III. (HRR)'
# Fetching topic for 'Friedrich III. von Saarwerden'
# Fetching topic for 'Friedrich der Schöne'
# Fetching topic for 'Frühmittelalter'
# Fetching topic for 'Fürstpropstei Berchtesgaden'
# Fetching topic for 'Gero'
# Fetching topic for 'Heiliges Römisches Reich'
# Fetching topic for 'Heinrich der Löwe'
# Fetching topic for 'Heinrich I. (Ostfrankenreich)'
# Fetching topic for 'Heinrich II. (HRR)'
# Fetching topic for 'Heinrich III. (HRR)'
# Fetching topic for 'Heinrich IV. (HRR)'
# Fetching topic for 'Heinrich V. (HRR)'
# Fetching topic for 'Heinrich VII. (HRR)'
# Fetching topic for 'Heiratsurkunde der Kaiserin Theophanu'
# Fetching topic for 'Hermann Billung'
# Fetching topic for 'Jacza von Köpenick'
# Fetching topic for 'Karl der Große'
# Fetching topic for 'Karl Martell'
# Fetching topic for 'Konrad I. (Ostfrankenreich)'
# Fetching topic for 'Konrad II. (HRR)'
# Fetching topic for 'Konrad III. (HRR)'
# Fetching topic for 'Krönungsmantel'
# Fetching topic for 'Krönung der römisch-deutschen Könige und Kaiser'
# Fetching topic for 'Liudger (Billunger)'
# Fetching topic for 'Ludwig IV. (HRR)'
# Fetching topic for 'Ludwig VII. (Bayern)'
# Fetching topic for 'Ludwig der Deutsche'
# Fetching topic for 'Marguerite Porete'
# Fetching topic for 'Mathilde von Canossa'
# Fetching topic for 'Cosimo de’ Medici'
# Fetching topic for 'Mistislaw'
# Fetching topic for 'Mojmir I.'
# Fetching topic for 'Niklot'
# Fetching topic for 'Otto I. (HRR)'
# Fetching topic for 'Otto II. (HRR)'
# Fetching topic for 'Otto III. (HRR)'
# Fetching topic for 'Otto IV. (HRR)'
# Fetching topic for 'Philipp von Schwaben'
# Fetching topic for 'Republik Venedig'
# Fetching topic for 'Reichskrone'
# Fetching topic for 'Reichsschwert'
# Fetching topic for 'Richard Löwenherz'
# Fetching topic for 'Rudolf I. (HRR)'
# Fetching topic for 'Samo'
# Fetching topic for 'Schlacht bei Tannenberg (1410)'
# Fetching topic for 'Straubing-Holland'
# Fetching topic for 'Thietmar von Merseburg'
# Fetching topic for 'Ulrich von Jungingen'
# Fetching topic for 'Yongle'
# Fetching topic for 'Zeremonialschwert (Essen)'
# Fetching topic for 'John Adams'
# Fetching topic for 'John Colter'Fetching topic for 'Aaron Burr'
#
# Fetching topic for 'Johannes Brenz'
# Fetching topic for 'Devolutionskrieg'

# %%
from collections import defaultdict


def categorize_articles(titles, lang="de"):
    def get_instance_or_subclass(wikidata_id, lang):
        url = "https://www.wikidata.org/w/api.php"
        params = {
            "action": "wbgetentities",
            "format": "json",
            "ids": wikidata_id,
            "props": "claims",
            "languages": lang,
        }
        response = requests.get(url, params=params)
        data = response.json()

        if "error" in data:
            return None

        instance_claims = data["entities"][wikidata_id]["claims"].get("P31", [])
        subclass_claims = data["entities"][wikidata_id]["claims"].get("P279", [])
        print(instance_claims)
        
        if not instance_claims and not subclass_claims:
            return None

        if instance_claims:
            instance_id = instance_claims[0]["mainsnak"]["datavalue"]["value"]["id"]
            return get_label(instance_id, lang)
        else:
            subclass_id = subclass_claims[0]["mainsnak"]["datavalue"]["value"]["id"]
            return get_label(subclass_id, lang)



    def get_category_for_topic(topic):
        category_map = {
            "human": ["Q5"],  # Human
            "taxon": ["Q16521"],  # Taxon
            "administrative territorial entity": ["Q56061"],  # Administrative territorial entity
            "architectural structure": ["Q811979"],  # Architectural structure
            "occurrence": ["Q1190554"],  # Occurrence
            "chemical compound": ["Q11173"],  # Chemical compound
            "film": ["Q11424"],  # Film
            "thoroughfare": ["Q83620"],  # Thoroughfare
            "astronomical object": ["Q6999"],  # Astronomical object
            "Wikimedia list article": ["Q13406463"],  # Wikimedia list article
            "Wikimedia disambiguation page": ["Q4167410"],  # Wikimedia disambiguation page
            "artificial entity": ["Q16686448"],  # Artificial entity
        }
        for category, topic_ids in category_map.items():
            if topic in topic_ids:
                return category
        print(topic)
        return "other"

    def find_matching_category(topic_id, lang="de"):
        current_id = topic_id
        while current_id is not None:
            category = get_category_for_topic(current_id)
            if category != "other":
                return category
            else:
                current_id = get_instance_or_subclass(current_id, lang)

        return "other"

    topic_counts = defaultdict(int)
    total_articles = len(titles)
    
    for title in titles:
        highest_level_topic = get_article_topic(title, lang)
        category = find_matching_category(highest_level_topic, lang)
        topic_counts[category] += 1

    topic_percentages = {
        category: (count / total_articles) * 100
        for category, count in topic_counts.items()
    }

    return topic_percentages


# Example usage
titles = ["Berlin", "Python (programming language)", "Mona Lisa", "The Shawshank Redemption"]
categories = categorize_articles(excellent_titles['title'].iloc[0:25])
for category, percentage in categories.items():
    print(f"{category}: {percentage:.1f}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 86
#      84 # Example usage
#      85 titles = ["Berlin", "Python (programming language)", "Mona Lisa", "The Shawshank Redemption"]
# ---> 86 categories = categorize_articles(excellent_titles['title'].iloc[0:25])
#      87 for category, percentage in categories.items():
#      88     print(f"{category}: {percentage:.1f}%")
#
# NameError: name 'excellent_titles' is not defined

# %%
for title in excellent_titles['title']:
    a = get_article_topic(title)
    print(f"{title} is in category: {a}")
# Out:
# Almsee is in category: See
# Altausseer See is in category: See
# Amper is in category: Fluss
# Bäke (Telte) is in category: Fluss
# Blabbergraben is in category: Bach
# Bullengraben is in category: Wassergraben
# Dornbirner Ach is in category: Fluss
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[149], line 2
#       1 for title in excellent_titles['title']:
# ----> 2     a = get_article_topic(title)
#       3     print(f"{title} is in category: {a}")
#
# Cell In[140], line 62, in get_article_topic(title, lang)
#      60 wikidata_id = get_wikidata_id(title, lang)
#      61 if wikidata_id:
# ---> 62     topic = get_instance_or_subclass(wikidata_id, lang)
#      63     return topic
#      64 else:
#
# Cell In[140], line 47, in get_article_topic.<locals>.get_instance_or_subclass(wikidata_id, lang)
#      39 url = "https://www.wikidata.org/w/api.php"
#      40 params = {
#      41     "action": "wbgetentities",
#      42     "format": "json",
#    (...)
#      45     "languages": lang,
#      46 }
# ---> 47 response = requests.get(url, params=params)
#      48 data = response.json()
#      50 instance_claims = data["entities"][wikidata_id]["claims"].get("P31", [])
#
# File ~/miniconda3/envs/jannis-env9/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/jannis-env9/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/jannis-env9/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/miniconda3/envs/jannis-env9/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/jannis-env9/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/miniconda3/envs/jannis-env9/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/miniconda3/envs/jannis-env9/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/miniconda3/envs/jannis-env9/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/miniconda3/envs/jannis-env9/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~/miniconda3/envs/jannis-env9/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~/miniconda3/envs/jannis-env9/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/jannis-env9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/miniconda3/envs/jannis-env9/lib/python3.9/ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/jannis-env9/lib/python3.9/ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import requests


def get_highest_level_categories(title, lang='de'):
    S = requests.Session()
    URL = f"https://{lang}.wikipedia.org/w/api.php"

    def get_categories(title, main_category=None):
        params = {
            "action": "query",
            "format": "json",
            "prop": "categories",
            "titles": title,
            "cllimit": "max",
        }

        if main_category:
            params["clcategories"] = main_category
        # print(params)
        # print(main_category)
        response = S.get(url=URL, params=params)
        data = response.json()
        print(data)
        categories = []
        for _, v in data["query"]["pages"].items():
            if "categories" in v:
                for category_info in v["categories"]:
                    category = category_info["title"]
                    categories.append(category)

        return categories

    categories = get_categories(title)
    highest_level_categories = []

    for category in categories:
        subcategories = get_categories(category)
        is_highest_level = True
        for subcategory in subcategories:
            if subcategory.startswith("Kategorie:Kategorie:"):
                is_highest_level = False
                break
        if is_highest_level:
            highest_level_categories.append(category)

    return highest_level_categories


# Example usage:
german_title = "Berlin"
result = get_highest_level_categories(german_title)
print(result)
# Out:
# {'batchcomplete': '', 'query': {'pages': {'2552494': {'pageid': 2552494, 'ns': 0, 'title': 'Berlin', 'categories': [{'ns': 14, 'title': 'Kategorie:Berlin'}, {'ns': 14, 'title': 'Kategorie:Bundesland (Deutschland)'}, {'ns': 14, 'title': 'Kategorie:Deutsche Hauptstadt'}, {'ns': 14, 'title': 'Kategorie:Deutsche Landeshauptstadt'}, {'ns': 14, 'title': 'Kategorie:Deutsche Universitätsstadt'}, {'ns': 14, 'title': 'Kategorie:Deutscher Ortsname slawischer Herkunft'}, {'ns': 14, 'title': 'Kategorie:Ehemalige Kreisstadt'}, {'ns': 14, 'title': 'Kategorie:Ersterwähnung 1244'}, {'ns': 14, 'title': 'Kategorie:Gemeinde in Deutschland'}, {'ns': 14, 'title': 'Kategorie:Hansestadt'}, {'ns': 14, 'title': 'Kategorie:Hauptstadt in Europa'}, {'ns': 14, 'title': 'Kategorie:Hauptstadt in der EU'}, {'ns': 14, 'title': 'Kategorie:Kreisfreie Stadt in Deutschland'}, {'ns': 14, 'title': 'Kategorie:Millionenstadt'}, {'ns': 14, 'title': 'Kategorie:Ort an der Spree'}, {'ns': 14, 'title': 'Kategorie:Ort in Berlin'}, {'ns': 14, 'title': 'Kategorie:Ort mit Binnenhafen'}, {'ns': 14, 'title': 'Kategorie:Stadt als Namensgeber für einen Asteroiden'}, {'ns': 14, 'title': 'Kategorie:Stadt in Deutschland'}, {'ns': 14, 'title': 'Kategorie:Wikipedia:Artikel mit Video'}, {'ns': 14, 'title': 'Kategorie:Wikipedia:Defekte Weblinks/Ungeprüfte Archivlinks 2023-03'}, {'ns': 14, 'title': 'Kategorie:Wikipedia:Gesprochener Artikel'}, {'ns': 14, 'title': 'Kategorie:Wikipedia:Lesenswert'}, {'ns': 14, 'title': 'Kategorie:Wikipedia:Veraltet in drei bis vier Jahren'}, {'ns': 14, 'title': 'Kategorie:Wikipedia:Weblink offline'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'239874': {'pageid': 239874, 'ns': 14, 'title': 'Kategorie:Berlin', 'categories': [{'ns': 14, 'title': 'Kategorie:Deutschland nach Bundesland'}, {'ns': 14, 'title': 'Kategorie:Deutschland nach Gemeinde'}, {'ns': 14, 'title': 'Kategorie:Europa nach Gemeinde'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'304105': {'pageid': 304105, 'ns': 14, 'title': 'Kategorie:Bundesland (Deutschland)', 'categories': [{'ns': 14, 'title': 'Kategorie:Föderalismus in Deutschland'}, {'ns': 14, 'title': 'Kategorie:Oberste Verwaltungseinheit nach Staat'}, {'ns': 14, 'title': 'Kategorie:Verwaltungseinheit in Deutschland'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'637628': {'pageid': 637628, 'ns': 14, 'title': 'Kategorie:Deutsche Hauptstadt', 'categories': [{'ns': 14, 'title': 'Kategorie:Gemeinde in Deutschland'}, {'ns': 14, 'title': 'Kategorie:Hauptstadt in Europa'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'556641': {'pageid': 556641, 'ns': 14, 'title': 'Kategorie:Deutsche Landeshauptstadt', 'categories': [{'ns': 14, 'title': 'Kategorie:Deutsche Hauptstadt'}, {'ns': 14, 'title': 'Kategorie:Hauptort einer Verwaltungseinheit'}, {'ns': 14, 'title': 'Kategorie:Verwaltungsgliederung Deutschlands'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'10402962': {'pageid': 10402962, 'ns': 14, 'title': 'Kategorie:Deutsche Universitätsstadt', 'categories': [{'ns': 14, 'title': 'Kategorie:Hochschul- oder Universitätsstadt'}, {'ns': 14, 'title': 'Kategorie:Ort in Deutschland'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'12125652': {'pageid': 12125652, 'ns': 14, 'title': 'Kategorie:Deutscher Ortsname slawischer Herkunft', 'categories': [{'ns': 14, 'title': 'Kategorie:Slawische Sprachen'}, {'ns': 14, 'title': 'Kategorie:Toponomastik'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'5716679': {'pageid': 5716679, 'ns': 14, 'title': 'Kategorie:Ehemalige Kreisstadt', 'categories': [{'ns': 14, 'title': 'Kategorie:Ehemalige Verwaltungsgliederung Deutschlands'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'9469227': {'pageid': 9469227, 'ns': 14, 'title': 'Kategorie:Ersterwähnung 1244', 'categories': [{'ns': 14, 'title': 'Kategorie:1244'}, {'ns': 14, 'title': 'Kategorie:Ersterwähnung im 13. Jahrhundert'}, {'ns': 14, 'title': 'Kategorie:Ersterwähnung nach Jahr'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'2335873': {'pageid': 2335873, 'ns': 14, 'title': 'Kategorie:Gemeinde in Deutschland', 'categories': [{'ns': 14, 'title': 'Kategorie:Gemeinde nach Staat'}, {'ns': 14, 'title': 'Kategorie:Geographie (Deutschland)'}, {'ns': 14, 'title': 'Kategorie:Kommunalpolitik (Deutschland)'}, {'ns': 14, 'title': 'Kategorie:Körperschaft des öffentlichen Rechts (Deutschland)'}, {'ns': 14, 'title': 'Kategorie:Verwaltungseinheit in Deutschland'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'2693197': {'pageid': 2693197, 'ns': 14, 'title': 'Kategorie:Hansestadt', 'categories': [{'ns': 14, 'title': 'Kategorie:Hanse'}, {'ns': 14, 'title': 'Kategorie:Stadt'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'637519': {'pageid': 637519, 'ns': 14, 'title': 'Kategorie:Hauptstadt in Europa', 'categories': [{'ns': 14, 'title': 'Kategorie:Geographie (Europa)'}, {'ns': 14, 'title': 'Kategorie:Hauptstadt'}, {'ns': 14, 'title': 'Kategorie:Politik (Europa)'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'1414345': {'pageid': 1414345, 'ns': 14, 'title': 'Kategorie:Hauptstadt in der EU', 'categories': [{'ns': 14, 'title': 'Kategorie:Europäische Union'}, {'ns': 14, 'title': 'Kategorie:Hauptstadt in Europa'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'2471937': {'pageid': 2471937, 'ns': 14, 'title': 'Kategorie:Kreisfreie Stadt in Deutschland', 'categories': [{'ns': 14, 'title': 'Kategorie:Stadt in Deutschland'}, {'ns': 14, 'title': 'Kategorie:Verwaltungsgliederung Deutschlands'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'2270187': {'pageid': 2270187, 'ns': 14, 'title': 'Kategorie:Millionenstadt', 'categories': [{'ns': 14, 'title': 'Kategorie:Ort nach Eigenschaft'}, {'ns': 14, 'title': 'Kategorie:Stadt'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'6687598': {'pageid': 6687598, 'ns': 14, 'title': 'Kategorie:Ort an der Spree', 'categories': [{'ns': 14, 'title': 'Kategorie:Ort nach Fluss'}, {'ns': 14, 'title': 'Kategorie:Spree'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'273267': {'pageid': 273267, 'ns': 14, 'title': 'Kategorie:Ort in Berlin', 'categories': [{'ns': 14, 'title': 'Kategorie:Geographie (Berlin)'}, {'ns': 14, 'title': 'Kategorie:Ort in Deutschland'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'1706000': {'pageid': 1706000, 'ns': 14, 'title': 'Kategorie:Ort mit Binnenhafen', 'categories': [{'ns': 14, 'title': 'Kategorie:Ort nach Eigenschaft'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'10996151': {'pageid': 10996151, 'ns': 14, 'title': 'Kategorie:Stadt als Namensgeber für einen Asteroiden', 'categories': [{'ns': 14, 'title': 'Kategorie:Ort als Namensgeber für einen Asteroiden'}, {'ns': 14, 'title': 'Kategorie:Stadt'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'10231460': {'pageid': 10231460, 'ns': 14, 'title': 'Kategorie:Stadt in Deutschland', 'categories': [{'ns': 14, 'title': 'Kategorie:Gemeinde in Deutschland'}, {'ns': 14, 'title': 'Kategorie:Stadt nach Staat'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'8206823': {'pageid': 8206823, 'ns': 14, 'title': 'Kategorie:Wikipedia:Artikel mit Video', 'categories': [{'ns': 14, 'title': 'Kategorie:Kategorie:Versteckt'}, {'ns': 14, 'title': 'Kategorie:Wikipedia:Artikel'}, {'ns': 14, 'title': 'Kategorie:Wikipedia:Videos für Wikipedia-Artikel'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'12579560': {'pageid': 12579560, 'ns': 14, 'title': 'Kategorie:Wikipedia:Defekte Weblinks/Ungeprüfte Archivlinks 2023-03', 'categories': [{'ns': 14, 'title': 'Kategorie:Kategorie:Versteckt'}, {'ns': 14, 'title': 'Kategorie:Wikipedia:Defekte Weblinks/Ungeprüfte Archivlinks/2023'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'5790086': {'pageid': 5790086, 'ns': 14, 'title': 'Kategorie:Wikipedia:Gesprochener Artikel', 'categories': [{'ns': 14, 'title': 'Kategorie:Wikipedia:Gesprochene Wikipedia'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'3595032': {'pageid': 3595032, 'ns': 14, 'title': 'Kategorie:Wikipedia:Lesenswert', 'categories': [{'ns': 14, 'title': 'Kategorie:Wikipedia:Bewertete Seite'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'11648899': {'pageid': 11648899, 'ns': 14, 'title': 'Kategorie:Wikipedia:Veraltet in drei bis vier Jahren', 'categories': [{'ns': 14, 'title': 'Kategorie:Kategorie:Versteckt'}, {'ns': 14, 'title': 'Kategorie:Wikipedia:Zukunft'}]}}}, 'limits': {'categories': 500}}
# {'batchcomplete': '', 'query': {'pages': {'7225395': {'pageid': 7225395, 'ns': 14, 'title': 'Kategorie:Wikipedia:Weblink offline', 'categories': [{'ns': 14, 'title': 'Kategorie:Kategorie:Versteckt'}, {'ns': 14, 'title': 'Kategorie:Wikipedia:Defekte Weblinks'}]}}}, 'limits': {'categories': 500}}
# ['Kategorie:Berlin', 'Kategorie:Bundesland (Deutschland)', 'Kategorie:Deutsche Hauptstadt', 'Kategorie:Deutsche Landeshauptstadt', 'Kategorie:Deutsche Universitätsstadt', 'Kategorie:Deutscher Ortsname slawischer Herkunft', 'Kategorie:Ehemalige Kreisstadt', 'Kategorie:Ersterwähnung 1244', 'Kategorie:Gemeinde in Deutschland', 'Kategorie:Hansestadt', 'Kategorie:Hauptstadt in Europa', 'Kategorie:Hauptstadt in der EU', 'Kategorie:Kreisfreie Stadt in Deutschland', 'Kategorie:Millionenstadt', 'Kategorie:Ort an der Spree', 'Kategorie:Ort in Berlin', 'Kategorie:Ort mit Binnenhafen', 'Kategorie:Stadt als Namensgeber für einen Asteroiden', 'Kategorie:Stadt in Deutschland', 'Kategorie:Wikipedia:Gesprochener Artikel', 'Kategorie:Wikipedia:Lesenswert']

# %%
def get_wikipedia_categories(title):
    url = "https://en.wikipedia.org/w/api.php"

    params = {
        "action": "query",
        "format": "json",
        "titles": title,
        "prop": "categories",
        "clshow": "!hidden",  # Exclude hidden categories
        "cllimit": "max"  # Get all categories
    }

    response = requests.get(url, params=params)
    data = response.json()

    # Extract page data
    page = data["query"]["pages"]
    page_id = list(page.keys())[0]

    # Extract categories
    categories = [cat["title"] for cat in page[page_id].get("categories", [])]
    return categories


# Example usage
title = "Python (programming language)"
categories = get_wikipedia_categories(title)

for category in categories:
    print(category)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 27
#      25 # Example usage
#      26 title = "Python (programming language)"
# ---> 27 categories = get_wikipedia_categories(title)
#      29 for category in categories:
#      30     print(category)
#
# Cell In[1], line 13, in get_wikipedia_categories(title)
#       2 url = "https://en.wikipedia.org/w/api.php"
#       4 params = {
#       5     "action": "query",
#       6     "format": "json",
#    (...)
#      10     "cllimit": "max"  # Get all categories
#      11 }
# ---> 13 response = requests.get(url, params=params)
#      14 data = response.json()
#      16 # Extract page data
#
# NameError: name 'requests' is not defined

# %%
second_relevant_topic = [
    'Kategorie:Räumliche Systematik', 'Kategorie:Sachsystematik', 'Kategorie:Zeitliche Semantik'
]

# %%
def get_categories(title):
    S = requests.Session()
    URL = f"https://de.wikipedia.org/w/api.php"
    params = {"action": "query", "format": "json", "prop": "categories", "titles": title}
    response = S.get(url=URL, params=params)
    data = response.json()
    categories_titles = [
        category['title'] for page_key in data['query']['pages']
        for category in data['query']['pages'][page_key]['categories']
        if category['title'].startswith('Kategorie:')
    ]
    print(categories_titles)

    return categories_titles

# %%
third_level_cats=[]
article_name='Berlin'

def get_3rd_level_hierarchy(category):

    initial_cateogries = get_categories('Berlin')
# Out:
# {'pages': {'2552494': {'pageid': 2552494,
#    'ns': 0,
#    'title': 'Berlin',
#    'categories': [{'ns': 14, 'title': 'Kategorie:Berlin'},
#     {'ns': 14, 'title': 'Kategorie:Bundesland (Deutschland)'},
#     {'ns': 14, 'title': 'Kategorie:Deutsche Hauptstadt'},
#     {'ns': 14, 'title': 'Kategorie:Deutsche Landeshauptstadt'},
#     {'ns': 14, 'title': 'Kategorie:Deutsche Universitätsstadt'},
#     {'ns': 14, 'title': 'Kategorie:Deutscher Ortsname slawischer Herkunft'},
#     {'ns': 14, 'title': 'Kategorie:Ehemalige Kreisstadt'},
#     {'ns': 14, 'title': 'Kategorie:Ersterwähnung 1244'},
#     {'ns': 14, 'title': 'Kategorie:Gemeinde in Deutschland'},
#     {'ns': 14, 'title': 'Kategorie:Hansestadt'}]}}}

# %%
categories_titles = [
    category['title'] for page_key in data['query']['pages']
    for category in data['query']['pages'][page_key]['categories']
    if category['title'].startswith('Kategorie:')
]
print(categories_titles)
# Out:
# ['Kategorie:Berlin', 'Kategorie:Bundesland (Deutschland)', 'Kategorie:Deutsche Hauptstadt', 'Kategorie:Deutsche Landeshauptstadt', 'Kategorie:Deutsche Universitätsstadt', 'Kategorie:Deutscher Ortsname slawischer Herkunft', 'Kategorie:Ehemalige Kreisstadt', 'Kategorie:Ersterwähnung 1244', 'Kategorie:Gemeinde in Deutschland', 'Kategorie:Hansestadt']

# %%
get_article_categories("Berlin")
# Out:
# ['Berlin',
#  'Bundesland (Deutschland)',
#  'Deutsche Hauptstadt',
#  'Deutsche Landeshauptstadt',
#  'Deutsche Universitätsstadt',
#  'Deutscher Ortsname slawischer Herkunft',
#  'Ehemalige Kreisstadt',
#  'Ersterwähnung 1244',
#  'Gemeinde in Deutschland',
#  'Hansestadt',
#  'Hauptstadt in Europa',
#  'Hauptstadt in der EU',
#  'Kreisfreie Stadt in Deutschland',
#  'Millionenstadt',
#  'Ort an der Spree',
#  'Ort in Berlin',
#  'Ort mit Binnenhafen',
#  'Stadt als Namensgeber für einen Asteroiden',
#  'Stadt in Deutschland',
#  'Wikipedia:Artikel mit Video',
#  'Wikipedia:Defekte Weblinks/Ungeprüfte Archivlinks 2023-03',
#  'Wikipedia:Gesprochener Artikel',
#  'Wikipedia:Lesenswert',
#  'Wikipedia:Veraltet in drei bis vier Jahren',
#  'Wikipedia:Weblink offline']
