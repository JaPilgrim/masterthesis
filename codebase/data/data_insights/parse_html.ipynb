# %%
from bs4 import BeautifulSoup, Tag, NavigableString
from collections import defaultdict
import re
from itertools import islice
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from googletrans import Translator

# %%
drop_dict_list = [
    'Meine Werkzeuge', 'Namensräume', 'Ansichten', 'Navigation', 'Mitmachen', 'Werkzeuge',
    'Drucken/\u200bexportieren', 'In anderen Projekten', 'In anderen Sprachen'
]

def translate_german_to_english(text):
    translator = Translator(service_urls=['translate.google.com'])
    translated_text = translator.translate(text, src='de', dest='en')
    return translated_text.text

def count_items(html_content):
    # translator = Translator(service_urls=['translate.google.com'])
    soup = BeautifulSoup(html_content, 'html.parser')
    string_soup = str(soup)
    category_dict ={}
    split_pattern = r'(<p><b>(?!<))'
    drop_topic_list = [
        'Meine Werkzeuge', 'Namensräume', 'Ansichten', 'Navigation', 'Mitmachen', 'Werkzeuge',
        'Drucken/\u200bexportieren', 'In anderen Projekten', 'In anderen Sprachen'
    ]
    # Split the text using the regex pattern and preserve the split value
    split_text = re.split(split_pattern, string_soup)

    split_text = [s for s in split_text if s]

    for text in split_text:
        if ':</b>' not in text:
            continue
        current_count = text.count('<a href="/wiki/')
        current_split = text.split(':</b>')
        current_name = current_split[0]
        # current_name = translator.translate(current_name)
        category_dict[current_name] = current_count


    h3_tags = soup.find_all('h3')
    split_h3 = string_soup.split('<h3')

    topic_count = {}
    for i, h3_tag in enumerate(h3_tags):
        topic_title = h3_tag.text.strip()
        if topic_title in drop_topic_list:
            continue
        topic_title = topic_title.replace("\n", " ")
        topic_title = re.sub(r'\s+', ' ', topic_title)
        # topic_title = translator.translate(topic_title)
        if not  isinstance(topic_title,str):
            topic_title = topic_title.text
        # if topic_title == 'Story':
        #     topic_title = 'History'
        # if topic_title == 'Gesellschaft':
        #     topic_title = 'Society'
        current_passage = split_h3[(i + 1)]
        current_count = current_passage.count('<a href="/wiki/')
        topic_count[topic_title] = current_count


    return category_dict, topic_count

# %%
# Assuming the function count_elements is already defined

# Replace 'your_html_file.html' with the path to your HTML file
with open('data/data_files/data_insights/excellent_html_full.html', 'r', encoding='utf-8') as file:
    html_content = file.read()
    print(html_content)

excellent_cats, excellent_topics = count_items(html_content)
for key in drop_dict_list:
    excellent_topics.pop(key, None)

print(excellent_cats)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="de" dir="ltr">
#
# <head>
#     <meta charset="UTF-8" />
#     <title>Wikipedia:Exzellente Artikel – Wikipedia</title>
#     <script>document.documentElement.className = "client-js"; (function () { var cookie = document.cookie.match(/(?:^|; )dewikimwclientprefs=([^;]+)/); if (cookie) { var featureName = cookie[1]; document.documentElement.className = document.documentElement.className.replace(featureName + '-enabled', featureName + '-disabled'); } }()); RLCONF = {
#             "wgBreakFrames": false, "wgSeparatorTransformTable": [",\t.", ".\t,"], "wgDigitTransformTable": ["", ""], "wgDefaultDateFormat": "dmy", "wgMonthNames": ["", "Januar", "Februar", "März", "April", "Mai", "Juni", "Juli", "August", "September", "Oktober", "November", "Dezember"], "wgRequestId": "c3b1ae96-12b6-4d2e-b520-a2eb4c9a26d9", "wgCSPNonce": false, "wgCanonicalNamespace": "Project", "wgCanonicalSpecialPageName": false, "wgNamespaceNumber": 4, "wgPageName": "Wikipedia:Exzellente_Artikel", "wgTitle": "Exzellente Artikel", "wgCurRevisionId": 226867737, "wgRevisionId": 226867737, "wgArticleId": 1468, "wgIsArticle": true, "wgIsRedirect": false, "wgAction": "view", "wgUserName": null, "wgUserGroups": ["*"], "wgCategories": [
#                 "Wikipedia:Exzellent"], "wgPageContentLanguage": "de", "wgPageContentModel": "wikitext", "wgRelevantPageName": "Wikipedia:Exzellente_Artikel", "wgRelevantArticleId": 1468, "wgIsProbablyEditable": false, "wgRelevantPageIsProbablyEditable": false, "wgRestrictionEdit": ["autoconfirmed"], "wgRestrictionMove": ["autoconfirmed"], "wgFlaggedRevsParams": { "tags": { "accuracy": { "levels": 1 } } }, "wgVisualEditor": { "pageLanguageCode": "de", "pageLanguageDir": "ltr", "pageVariantFallbacks": "de" }, "wgMFDisplayWikibaseDescriptions": { "search": true, "watchlist": true, "tagline": true, "nearby": true }, "wgWMESchemaEditAttemptStepOversample": false, "wgWMEPageLength": 800, "wgNoticeProject": "wikipedia", "wgMediaViewerOnClick": true, "wgMediaViewerEnabledByDefault": true, "wgPopupsFlags": 4, "wgULSCurrentAutonym": "Deutsch", "wgEditSubmitButtonLabelPublish": true, "wgCentralAuthMobileDomain": false, "wgDiscussionToolsFeaturesEnabled": {
#                     "replytool": true, "newtopictool": true, "sourcemodetoolbar": true, "topicsubscription": false, "autotopicsub": false,
#                     "visualenhancements": false, "visualenhancements_reply": false, "visualenhancements_pageframe": false
#                 }, "wgDiscussionToolsFallbackEditMode": "visual", "wgULSPosition": "interlanguage", "wgULSisCompactLinksEnabled": true, "wgULSisLanguageSelectorEmpty": false, "wgWikibaseItemId": "Q16465", "GEHomepageSuggestedEditsEnableTopics": true, "wgGETopicsMatchModeEnabled": false, "wgGEStructuredTaskRejectionReasonTextInputEnabled": false, "wgGELevelingUpEnabledForUser": false
#         }; RLSTATE = { "ext.gadget.citeRef": "ready", "ext.globalCssJs.user.styles": "ready", "site.styles": "ready", "user.styles": "ready", "ext.globalCssJs.user": "ready", "user": "ready", "user.options": "loading", "ext.discussionTools.init.styles": "ready", "oojs-ui-core.styles": "ready", "oojs-ui.styles.indicators": "ready", "mediawiki.widgets.styles": "ready", "oojs-ui-core.icons": "ready", "skins.vector.styles.legacy": "ready", "ext.visualEditor.desktopArticleTarget.noscript": "ready", "ext.wikimediaBadges": "ready", "ext.uls.interlanguage": "ready", "wikibase.client.init": "ready" };
#         RLPAGEMODULES = ["site", "mediawiki.page.ready", "skins.vector.legacy.js", "mmv.head", "mmv.bootstrap.autostart", "ext.visualEditor.desktopArticleTarget.init", "ext.visualEditor.targetLoader", "ext.eventLogging", "ext.wikimediaEvents", "ext.navigationTiming", "ext.cx.eventlogging.campaigns", "ext.centralNotice.geoIP", "ext.centralNotice.startUp", "ext.gadget.WikiMiniAtlas", "ext.gadget.OpenStreetMap", "ext.gadget.CommonsDirekt", "ext.gadget.desktopHauptseite", "ext.centralauth.centralautologin", "ext.popups", "ext.echo.centralauth", "ext.discussionTools.init", "ext.uls.compactlinks", "ext.uls.interface"];</script>
#     <script>(RLQ = window.RLQ || []).push(function () { mw.loader.implement("user.options@12s5i", function ($, jQuery, require, module) { mw.user.tokens.set({ "patrolToken": "+\\", "watchToken": "+\\", "csrfToken": "+\\" }); }); });</script>
#     <link rel="stylesheet"
#         href="/w/load.php?lang=de&amp;modules=ext.discussionTools.init.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.widgets.styles%7Coojs-ui-core.icons%2Cstyles%7Coojs-ui.styles.indicators%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" />
#     <script async="" src="/w/load.php?lang=de&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>
#     <meta name="ResourceLoaderDynamicStyles" content="" />
#     <link rel="stylesheet" href="/w/load.php?lang=de&amp;modules=ext.gadget.citeRef&amp;only=styles&amp;skin=vector" />
#     <link rel="stylesheet" href="/w/load.php?lang=de&amp;modules=site.styles&amp;only=styles&amp;skin=vector" />
#     <meta name="generator" content="MediaWiki 1.41.0-wmf.6" />
#     <meta name="referrer" content="origin" />
#     <meta name="referrer" content="origin-when-crossorigin" />
#     <meta name="referrer" content="origin-when-cross-origin" />
#     <meta name="robots" content="max-image-preview:standard" />
#     <meta name="format-detection" content="telephone=no" />
#     <meta name="viewport" content="width=1000" />
#     <meta property="og:title" content="Wikipedia:Exzellente Artikel – Wikipedia" />
#     <meta property="og:type" content="website" />
#     <link rel="preconnect" href="//upload.wikimedia.org" />
#     <link rel="alternate" media="only screen and (max-width: 720px)"
#         href="//de.m.wikipedia.org/wiki/Wikipedia:Exzellente_Artikel" />
#     <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png" />
#     <link rel="icon" href="/static/favicon/wikipedia.ico" />
#     <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php"
#         title="Wikipedia (de)" />
#     <link rel="EditURI" type="application/rsd+xml" href="//de.wikipedia.org/w/api.php?action=rsd" />
#     <link rel="canonical" href="https://de.wikipedia.org/wiki/Wikipedia:Exzellente_Artikel" />
#     <link rel="license" href="https://creativecommons.org/licenses/by-sa/3.0/" />
#     <link rel="alternate" type="application/atom+xml" title="Atom-Feed für „Wikipedia“"
#         href="/w/index.php?title=Spezial:Letzte_%C3%84nderungen&amp;feed=atom" />
#     <link rel="dns-prefetch" href="//meta.wikimedia.org" />
#     <link rel="dns-prefetch" href="//login.wikimedia.org" />
# </head>
#
# <body
#     class="ext-discussiontools-replytool-enabled ext-discussiontools-newtopictool-enabled ext-discussiontools-sourcemodetoolbar-enabled skin-vector-legacy mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-4 ns-subject page-Wikipedia_Exzellente_Artikel rootpage-Wikipedia_Exzellente_Artikel skin-vector action-view">
#     <div id="mw-page-base" class="noprint"></div>
#     <div id="mw-head-base" class="noprint"></div>
#     <div id="content" class="mw-body" role="main">
#         <a id="top"></a>
#         <div id="siteNotice"><!-- CentralNotice --></div>
#         <div class="mw-indicators">
#         </div>
#         <h1 id="firstHeading" class="firstHeading mw-first-heading"><span
#                 class="mw-page-title-namespace">Wikipedia</span><span class="mw-page-title-separator">:</span><span
#                 class="mw-page-title-main">Exzellente Artikel</span></h1>
#         <div id="bodyContent" class="vector-body">
#             <div id="siteSub" class="noprint">aus Wikipedia, der freien Enzyklopädie</div>
#             <div id="contentSub">
#                 <div id="mw-content-subtitle"></div>
#             </div>
#             <div id="contentSub2"></div>
#
#             <div id="jump-to-nav"></div>
#             <a class="mw-jump-link" href="#mw-head">Zur Navigation springen</a>
#             <a class="mw-jump-link" href="#searchInput">Zur Suche springen</a>
#             <div id="mw-content-text" class="mw-body-content mw-content-ltr" lang="de" dir="ltr">
#                 <div class="mw-parser-output">
#                     <div id="shortcut" class="shortcut noprint searchaux" data-shortcut="WP:EA"><a
#                             href="/wiki/Wikipedia:Shortcuts" title="Wikipedia:Shortcuts">Abkürzung</a>: WP:EA</div>
#                     <style data-mw-deduplicate="TemplateStyles:r201149660">
#                         .mw-parser-output ol.breadcrumb-nav-container,
#                         .mw-parser-output ul.breadcrumb-nav-container {
#                             list-style-image: none;
#                             list-style-position: outside;
#                             list-style-type: none;
#                             margin: 0.2em;
#                             padding-left: 0
#                         }
#
#                         .mw-parser-output ol.breadcrumb-nav-container>li,
#                         .mw-parser-output ul.breadcrumb-nav-container>li {
#                             display: inline;
#                             padding: 0
#                         }
#
#                         .mw-parser-output ol.breadcrumb-nav-container>li,
#                         .mw-parser-output ol.breadcrumb-nav-gt>li::before,
#                         .mw-parser-output ol.breadcrumb-nav-lt>li::before,
#                         .mw-parser-output ul.breadcrumb-nav-container>li,
#                         .mw-parser-output ul.breadcrumb-nav-gt>li::before,
#                         .mw-parser-output ul.breadcrumb-nav-lt>li::before {
#                             margin-right: 0.3em
#                         }
#
#                         .mw-parser-output ol.breadcrumb-nav-gt>li:nth-child(1n
#                             /**/
#                             +2)::before,
#                         .mw-parser-output ul.breadcrumb-nav-gt>li:nth-child(1n
#
#                             /**/
#                             +2)::before {
#                             content: "\3e "
#                         }
#
#                         .mw-parser-output ol.breadcrumb-nav-lt>li:nth-child(1n
#                             /**/
#                             +2)::before,
#                         .mw-parser-output ul.breadcrumb-nav-lt>li:nth-child(1n
#
#                             /**/
#                             +2)::before {
#                             content: "\3c "
#                         }
#
#                         .mw-parser-output ol.breadcrumb-nav-middot>li::after,
#                         .mw-parser-output ul.breadcrumb-nav-middot>li::after {
#                             content: "●";
#                             font-size: 85%;
#                             margin-left: 0.5em;
#                             vertical-align: top
#                         }
#
#                         .mw-parser-output ol.breadcrumb-nav-pipe>li::after,
#                         .mw-parser-output ul.breadcrumb-nav-pipe>li::after {
#                             content: "|";
#                             margin-left: 0.5em
#                         }
#
#                         .mw-parser-output ol.breadcrumb-nav-middot>li:last-child::after,
#                         .mw-parser-output ul.breadcrumb-nav-middot>li:last-child::after,
#                         .mw-parser-output ol.breadcrumb-nav-pipe>li:last-child::after,
#                         .mw-parser-output ul.breadcrumb-nav-pipe>li:last-child::after {
#                             display: none
#                         }
#
#                         @media screen and (max-width:799px) {
#                             .mw-parser-output .breadcrumb-nav-container.subpages {
#                                 display: none
#                             }
#                         }
#                     </style>
#                     <ol id="contentSub2"
#                         class="subpages noprint navigation-not-searchable breadcrumb-nav-container breadcrumb-nav-gt"
#                         style="list-style: outside none none; margin: 0 0 0.3em; padding-left: 0;" role="navigation">
#                         <li><a href="/wiki/Hilfe:Nachschlagen" title="Hilfe:Nachschlagen">Nachschlagen</a></li>
#                         <li><a href="/wiki/Wikipedia:Bewertungen" title="Wikipedia:Bewertungen">Bewertungen</a></li>
#                         <li><b>Exzellente Artikel</b></li>
#                     </ol>
#                     <table width="100%" style="background:#FFFFFF; border:solid 1px #479429;" cellspacing="0"
#                         cellpadding="10">
#
#                         <tbody>
#                             <tr>
#                                 <td colspan="2">
#                                     <div>[<a class="external text"
#                                             href="https://de.wikipedia.org/w/index.php?title=Wikipedia:Exzellente_Artikel/Intro&amp;action=edit">Bearbeiten</a>]
#                                     </div>
#                                     <p>Die folgenden <b>2793</b> Artikel (vgl. <a
#                                             href="/wiki/Wikipedia:Statistik_der_exzellenten_Artikel"
#                                             title="Wikipedia:Statistik der exzellenten Artikel">Statistik</a>) haben die
#                                         <a href="/wiki/Wikipedia:Wikipedianer"
#                                             title="Wikipedia:Wikipedianer">Wikipedianer</a> als <b>exzellente</b>
#                                         Artikel gewählt. Wenn du einen besonders guten Artikel gefunden hast, trage ihn
#                                         bei den <a href="/wiki/Wikipedia:Kandidaturen_von_Artikeln,_Listen_und_Portalen"
#                                             title="Wikipedia:Kandidaturen von Artikeln, Listen und Portalen">Kandidaturen
#                                             von Artikeln, Listen und Portalen</a> ein. Exzellente Illustrationen und
#                                         Fotos können bei den <a href="/wiki/Wikipedia:Exzellente_Bilder"
#                                             title="Wikipedia:Exzellente Bilder">exzellenten Bildern</a> bewertet werden.
#                                         Auf der Hauptseite wird jeden Tag ein Artikel <a
#                                             href="/wiki/Wikipedia:Hauptseite/Artikel_des_Tages"
#                                             title="Wikipedia:Hauptseite/Artikel des Tages">vorgestellt</a>. Eine
#                                         Übersicht über die früheren Artikel des Tages und die aktuellen Vorschläge
#                                         findet sich unter <a
#                                             href="/wiki/Wikipedia:Hauptseite/Artikel_des_Tages/Verwaltung"
#                                             title="Wikipedia:Hauptseite/Artikel des Tages/Verwaltung">Verwaltung Artikel
#                                             des Tages</a>. Eine weitere Artikelauswahl findet sich unter den <b><a
#                                                 href="/wiki/Wikipedia:Lesenswerte_Artikel"
#                                                 title="Wikipedia:Lesenswerte Artikel">lesenswerten Artikeln</a></b>.
#                                         Besonders gut ausgearbeitete Listen oder besonders ansprechende Portale finden
#                                         sich unter den <b><a href="/wiki/Wikipedia:Informative_Listen_und_Portale"
#                                                 title="Wikipedia:Informative Listen und Portale">informativen Listen und
#                                                 Portalen</a></b>. Ein paar Hinweise, wie du einen guten oder gar
#                                         exzellenten Artikel verfasst, gibt dir <a
#                                             href="/wiki/Wikipedia:Wie_schreibe_ich_gute_Artikel"
#                                             title="Wikipedia:Wie schreibe ich gute Artikel">diese Anleitung</a>. Die
#                                         Kriterien, die ein exzellenter Artikel erfüllen muss, findest du <a
#                                             href="/wiki/Wikipedia:Kandidaturen_von_Artikeln,_Listen_und_Portalen/Kriteriendarstellung"
#                                             title="Wikipedia:Kandidaturen von Artikeln, Listen und Portalen/Kriteriendarstellung">auf
#                                             dieser Seite</a>.
#                                     </p>
#                                     <div align="center"><b><a href="/wiki/Kategorie:Wikipedia:Exzellent"
#                                                 title="Kategorie:Wikipedia:Exzellent">Alphabetische Liste</a> · <a
#                                                 href="/wiki/Wikipedia:Exzellente_Artikel/nach_Datum"
#                                                 title="Wikipedia:Exzellente Artikel/nach Datum">nach Datum</a> · <a
#                                                 href="/wiki/Spezial:%C3%84nderungen_an_verlinkten_Seiten/Wikipedia:Exzellente_Artikel"
#                                                 title="Spezial:Änderungen an verlinkten Seiten/Wikipedia:Exzellente Artikel">Letzte
#                                                 Änderungen</a> · <a
#                                                 href="/wiki/Spezial:Zuf%C3%A4llig_in_Kategorie/Kategorie:Wikipedia:Exzellent"
#                                                 title="Spezial:Zufällig in Kategorie/Kategorie:Wikipedia:Exzellent">zufälliger
#                                                 exzellenter Artikel</a></b><br />
#                                         <p><a href="#Geographie">Geographie</a> · <a href="#Geschichte">Geschichte</a> ·
#                                             <a href="#Gesellschaft">Gesellschaft</a> · <a href="#Kunst_und_Kultur">Kunst
#                                                 und Kultur</a> · <a href="#Religion">Religion</a> · <a
#                                                 href="#Sport">Sport</a> · <a href="#Technik_und_Verkehr">Technik</a> ·
#                                             <a href="#Wissenschaft_und_Philosophie">Wissenschaft und Philosophie</a>
#                                         </p>
#                                     </div>
#                                 </td>
#                             </tr>
#                             <tr>
#                                 <td colspan="2">
#                                     <table cellspacing="0" style="border-collapse: collapse; width: 100%">
#                                         <tbody>
#                                             <tr>
#                                                 <td style="width: 35px;"><a href="/wiki/Datei:P_cal_euro-green.png"
#                                                         class="image"><img alt="P cal euro-green.png"
#                                                             src="//upload.wikimedia.org/wikipedia/commons/e/ee/P_cal_euro-green.png"
#                                                             decoding="async" width="35" height="39" data-file-width="30"
#                                                             data-file-height="33" /></a>
#                                                 </td>
#                                                 <td style="border-bottom: solid 2px #479429;">
#                                                     <div style="font-size: 1.2em; font-weight: bold; margin-top: .3em; margin-bottom: 0em; padding: 0; overflow: hidden;"
#                                                         class="Vorlage_Überschriftensimulation_3"
#                                                         id="Neu_bei_den_„Exzellenten“">Neu bei den „Exzellenten“</div>
#                                                 </td>
#                                                 <td style="border-bottom: solid 2px #479429;">
#                                                     <div>[<a class="external text"
#                                                             href="https://de.wikipedia.org/w/index.php?title=Wikipedia:Exzellente_Artikel/Neu&amp;action=edit">Bearbeiten</a>]
#                                                     </div>
#                                                 </td>
#                                             </tr>
#                                         </tbody>
#                                     </table>
#                                     <table cellpadding="10" border="0">
#
#                                         <tbody>
#                                             <tr>
#                                                 <td style="vertical-align:top;width:50%;text-align:justify;">
#                                                     <div class="floatright"><a
#                                                             href="/wiki/Datei:Coronation_scot_BNF.jpg" class="image"
#                                                             title="Coronation Class"><img alt="Coronation Class"
#                                                                 src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c0/Coronation_scot_BNF.jpg/100px-Coronation_scot_BNF.jpg"
#                                                                 decoding="async" width="100" height="84"
#                                                                 srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c0/Coronation_scot_BNF.jpg/150px-Coronation_scot_BNF.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c0/Coronation_scot_BNF.jpg/200px-Coronation_scot_BNF.jpg 2x"
#                                                                 data-file-width="5342" data-file-height="4463" /></a>
#                                                     </div>
#                                                     <p>Die Dampflokomotiven der <b>LMS-Klasse 7P „Coronation“</b>
#                                                         (englisch: <i>Coronation Class</i>; teilweise auch als
#                                                         <i>Princess Coronation Class, Coronation Scot Class, Duchess
#                                                             Class</i> oder <i>City Class</i> bezeichnet) wurden zwischen
#                                                         1937 und 1948 mit insgesamt 38 Stück von der britischen
#                                                         Bahngesellschaft London, Midland and Scottish Railway (LMS)
#                                                         beschafft. Die für den Expresszugdienst vorgesehenen
#                                                         Schlepptenderlokomotiven mit der Achsfolge 2’C1’ wurden von
#                                                         William Stanier, dem Chefingenieur der LMS, entworfen und in den
#                                                         Crewe Works der LMS in Crewe für den Einsatz auf der West Coast
#                                                         Main Line (WCML) zwischen London und Schottland erbaut. 24 der
#                                                         Maschinen wurden mit Verkleidung als Stromlinienlokomotiven
#                                                         gebaut, verloren diese aber in den Nachkriegsjahren. 1937
#                                                         erzielte die erste Maschine der Klasse mit 183,4 km/h einen
#                                                         Geschwindigkeitsrekord für britische Dampflokomotiven. Ab 1948
#                                                         gehörten die Maschinen zum Bestand von British Railways, nachdem
#                                                         die LMS infolge des Transport Act 1947 verstaatlicht worden war.
#                                                         Bis Ende der 1950er Jahre bespannten sie die meisten wichtigen
#                                                         Expresszüge auf der WCML, bevor sie allmählich durch
#                                                         Diesellokomotiven ersetzt wurden. In den Jahren 1962 bis 1964
#                                                         wurden die Lokomotiven ausgemustert. Drei Exemplare der Klasse
#                                                         blieben museal erhalten, davon ist noch eine betriebsfähig.
#                                                     </p>
#                                                     <p><b><a href="/wiki/LMS-Klasse_7P_%E2%80%9ECoronation%E2%80%9C"
#                                                                 title="LMS-Klasse 7P „Coronation“">Artikel lesen</a></b>
#                                                     </p>
#                                                 </td>
#                                                 <td style="vertical-align:top;width:50%;text-align:justify;">
#                                                     <div class="floatright"><a
#                                                             href="/wiki/Datei:James_Abram_Garfield,_photo_portrait_seated.jpg"
#                                                             class="image"><img
#                                                                 alt="James Abram Garfield, photo portrait seated.jpg"
#                                                                 src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1f/James_Abram_Garfield%2C_photo_portrait_seated.jpg/120px-James_Abram_Garfield%2C_photo_portrait_seated.jpg"
#                                                                 decoding="async" width="120" height="152"
#                                                                 srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1f/James_Abram_Garfield%2C_photo_portrait_seated.jpg/180px-James_Abram_Garfield%2C_photo_portrait_seated.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1f/James_Abram_Garfield%2C_photo_portrait_seated.jpg/240px-James_Abram_Garfield%2C_photo_portrait_seated.jpg 2x"
#                                                                 data-file-width="3182" data-file-height="4034" /></a>
#                                                     </div>
#                                                     <p><b>James Abram Garfield</b> (* 19. November 1831 in Orange
#                                                         Township (heutiges Moreland Hills), Cuyahoga County, Ohio; † 19.
#                                                         September 1881 in Elberon, Monmouth County, New Jersey) war ein
#                                                         amerikanischer Politiker (Republikanische Partei) und vom 4.
#                                                         März 1881 bis zu seinem Tod infolge eines Attentats der 20.
#                                                         Präsident der Vereinigten Staaten.
#                                                         Garfield wuchs in ärmlichen Verhältnissen im damaligen Grenzland
#                                                         (Frontier) als Halbwaise auf. Als überzeugter Anhänger des
#                                                         christlichen Restoration Movements („Erneuerungsbewegung“)
#                                                         besuchte er dessen Western Reserve Eclectic Institute (heutiges
#                                                         Hiram College) und wechselte später auf das Williams College, wo
#                                                         er seinen Abschluss machte. Danach war er Lehrer am Hiram
#                                                         College, bis er 1859 in die Politik ging und in den Senat von
#                                                         Ohio gewählt wurde. Parallel dazu studierte er Jura.
#                                                         Ab 1863 war er Abgeordneter im Repräsentantenhaus der
#                                                         Vereinigten Staaten und zählte anfangs zur Fraktion der
#                                                         radikalen Republikaner. Später näherte er sich den Half-Breeds
#                                                         („Mischlingen, Halbblütern“) an, die eine Verwaltungsreform zur
#                                                         Abschaffung des Spoilssystems („Beutesystem“) anstrebten. Ein
#                                                         zentrales Projekt für Garfield im Kongress war die Durchsetzung
#                                                         einer auf dem Goldstandard beruhenden antiinflationäre
#                                                         Hartgeldpolitik.
#                                                         Auf dem Nominierungsparteitag der Republikaner im Juni 1880
#                                                         konnte er sich als Überraschungssieger und Kompromisskandidat
#                                                         gegen Ulysses S. Grant und James G. Blaine durchsetzen. Nach
#                                                         seinem Sieg bei der Präsidentschaftswahl gegen den
#                                                         demokratischen Bewerber Winfield Scott Hancock war er nur für
#                                                         wenige Monate im Amt.
#                                                         Am 2. Juli 1881 wurde er bei einem Attentat von Charles J.
#                                                         Guiteau schwer verwundet und erlag seinen Verletzungen keine
#                                                         drei Monate später.
#                                                     </p>
#                                                     <p><b><a href="/wiki/James_A._Garfield"
#                                                                 title="James A. Garfield">Artikel lesen</a></b>
#                                                     </p>
#                                                 </td>
#                                             </tr>
#                                             <tr>
#                                                 <td style="vertical-align:top;width:50%;text-align:justify;">
#                                                     <div class="floatright"><a
#                                                             href="/wiki/Datei:SpN_Wagen_5_und_20_01.jpg"
#                                                             class="image"><img alt="SpN Wagen 5 und 20 01.jpg"
#                                                                 src="//upload.wikimedia.org/wikipedia/commons/thumb/d/db/SpN_Wagen_5_und_20_01.jpg/160px-SpN_Wagen_5_und_20_01.jpg"
#                                                                 decoding="async" width="160" height="91"
#                                                                 srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/db/SpN_Wagen_5_und_20_01.jpg/240px-SpN_Wagen_5_und_20_01.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/db/SpN_Wagen_5_und_20_01.jpg/320px-SpN_Wagen_5_und_20_01.jpg 2x"
#                                                                 data-file-width="2372" data-file-height="1352" /></a>
#                                                     </div>
#                                                     <p>Die <b>Elektrische Straßenbahn Spandau–Nonnendamm GmbH</b> (SpN)
#                                                         – umgangssprachlich <i>Nonnendammbahn</i> genannt – war ein
#                                                         zwischen 1909 und 1914 bestehendes Straßenbahnunternehmen, das
#                                                         aus einer 1908 von Siemens &amp; Halske errichteten
#                                                         Straßenbahnlinie hervorging. Drei Monate nach ihrer Gründung
#                                                         erwarb die damals selbstständige Stadt Spandau alle Anteile an
#                                                         der Bahn, deren Betriebsführung im Folgejahr von der Städtischen
#                                                         Straßenbahn Spandau übernommen wurde. Mit der Löschung der
#                                                         Nonnendammbahn aus dem Handelsregister im Jahr 1914 erfolgte die
#                                                         vollständige Eingliederung in die Spandauer Straßenbahn.
#                                                     </p>
#                                                     <p>Die von der Nonnendammbahn betriebene Strecke zwischen der
#                             <tr>
#                                 <td colspan="2">
#                                     <table cellspacing="0" style="border-collapse: collapse; width: 100%">
#                                         <tbody>
#                                             <tr>
#                                                 <td style="width: 35px;"><a href="/wiki/Datei:P_countries-green.png"
#                                                         class="image"><img alt="P countries-green.png"
#                                                             src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3d/P_countries-green.png/35px-P_countries-green.png"
#                                                             decoding="async" width="35" height="31"
#                                                             srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3d/P_countries-green.png/53px-P_countries-green.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3d/P_countries-green.png/70px-P_countries-green.png 2x"
#                                                             data-file-width="77" data-file-height="68" /></a>
#                                                 </td>
#                                                 <td style="border-bottom: solid 2px #479429;">
#                                                     <h3><span class="mw-headline" id="Geographie"
#                                                             data-mw-thread-id="h-Geographie"><span
#                                                                 data-mw-comment-start=""
#                                                                 id="h-Geographie"></span>Geographie<span
#                                                                 data-mw-comment-end="h-Geographie"></span></span></h3>
#                                                 </td>
#                                                 <td style="border-bottom: solid 2px #479429;">
#                                                     <div>[<a class="external text"
#                                                             href="https://de.wikipedia.org/w/index.php?title=Wikipedia:Exzellente_Artikel/Geographie&amp;action=edit">Bearbeiten</a>]
#                                                     </div>
#                                                 </td>
#                                             </tr>
#                                         </tbody>
#                                     </table>
#                                     <table border="0" style="font-size: 95%; width: 100%;">
#                                         <tbody>
#                                             <tr>
#                                                 <td style="vertical-align: top; width: 50%; padding: 10px">
#                                                     <p><b>Gewässer:</b>
#                                                         <a href="/wiki/Almsee" title="Almsee">Almsee</a> ·
#                                                         <a href="/wiki/Altausseer_See" title="Altausseer See">Altausseer
#                                                             See</a> ·
#                                                         <span class="noprint noviewer"><span aria-hidden="true"
#                                                                 role="presentation"><a
#                                                                     href="/wiki/Datei:Loudspeaker.svg" class="image"
#                                                                     title="Gesprochener Inhalt"><img alt=""
#                                                                         src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Loudspeaker.svg/12px-Loudspeaker.svg.png"
#                                                                         decoding="async" width="12" height="12"
#                                                                         srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Loudspeaker.svg/18px-Loudspeaker.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Loudspeaker.svg/24px-Loudspeaker.svg.png 2x"
#                                                                         data-file-width="20"
#                                                                         data-file-height="20" /></a></span></span> <a
#                                                             href="/wiki/Amper" title="Amper">Amper</a> ·
#                                                         <a href="/wiki/B%C3%A4ke_(Telte)" title="Bäke (Telte)">Bäke
#                                                             (Telte)</a> ·
#                                                         <a href="/wiki/Blabbergraben"
#                                                             title="Blabbergraben">Blabbergraben</a> ·
#                                                         <a href="/wiki/Bullengraben"
#                                                             title="Bullengraben">Bullengraben</a> ·
#                                                         <a href="/wiki/Dornbirner_Ach" title="Dornbirner Ach">Dornbirner
#                                                             Ach</a> ·
#                                                         <a href="/wiki/Elbe" title="Elbe">Elbe</a> ·
#                                                         <span class="noprint noviewer"><span aria-hidden="true"
#                                                                 role="presentation"><a
#                                                                     href="/wiki/Datei:Loudspeaker.svg" class="image"
#                                                                     title="Gesprochener Inhalt"><img alt=""
#                                                                         src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Loudspeaker.svg/12px-Loudspeaker.svg.png"
#                                                                         decoding="async" width="12" height="12"
#                                                                         srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8
#                                 href="https://zea.wikipedia.org/wiki/Wikipedia:Etalage"
#                                 title="Wikipedia:Etalage – Seeländisch" lang="zea" hreflang="zea"
#                                 class="interlanguage-link-target"><span>Zeêuws</span></a></li>
#                         <li class="interlanguage-link interwiki-zh mw-list-item"><a
#                                 href="https://zh.wikipedia.org/wiki/Wikipedia:%E5%85%B8%E8%8C%83%E6%9D%A1%E7%9B%AE"
#                                 title="Wikipedia:典范条目 – Chinesisch" lang="zh" hreflang="zh"
#                                 class="interlanguage-link-target"><span>中文</span></a></li>
#                         <li class="interlanguage-link interwiki-zh-classical mw-list-item"><a
#                                 href="https://zh-classical.wikipedia.org/wiki/%E7%B6%AD%E5%9F%BA%E5%A4%A7%E5%85%B8:%E5%8D%93%E8%91%97"
#                                 title="維基大典:卓著 – Klassisches Chinesisch" lang="lzh" hreflang="lzh"
#                                 class="interlanguage-link-target"><span>文言</span></a></li>
#                         <li class="interlanguage-link interwiki-zh-min-nan mw-list-item"><a
#                                 href="https://zh-min-nan.wikipedia.org/wiki/Wikipedia:S%C3%BAi-kh%C3%B9i_%C3%AA_b%C3%BBn-chiu%E2%81%BF"
#                                 title="Wikipedia:Súi-khùi ê bûn-chiuⁿ – Min Nan" lang="nan" hreflang="nan"
#                                 class="interlanguage-link-target"><span>Bân-lâm-gú</span></a></li>
#                         <li class="interlanguage-link interwiki-zh-yue mw-list-item"><a
#                                 href="https://zh-yue.wikipedia.org/wiki/Wikipedia:%E6%AD%A3%E6%96%87"
#                                 title="Wikipedia:正文 – Kantonesisch" lang="yue" hreflang="yue"
#                                 class="interlanguage-link-target"><span>粵語</span></a></li>
#                     </ul>
#                     <div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a
#                                 href="https://www.wikidata.org/wiki/Special:EntityPage/Q16465#sitelinks-wikipedia"
#                                 title="Links auf Artikel in anderen Sprachen bearbeiten" class="wbc-editpage">Links
#                                 bearbeiten</a></span></div>
#                 </div>
#             </nav>
#
#         </div>
#
#     </div>
#
#     <footer id="footer" class="mw-footer" role="contentinfo">
#         <ul id="footer-info">
#             <li id="footer-info-lastmod"> Diese Seite wurde zuletzt am 8. Oktober 2022 um 16:17 Uhr bearbeitet.</li>
#             <li id="footer-info-copyright">
#                 <div id="footer-info-copyright-stats" class="noprint"><a class="external"
#                         href="https://pageviews.wmcloud.org/?pages=Wikipedia:Exzellente_Artikel&amp;project=de.wikipedia.org"
#                         rel="nofollow">Abrufstatistik</a> </div>
#                 <div id="footer-info-copyright-separator"><br /></div>
#                 <div id="footer-info-copyright-info">
#                     Der Text ist unter der Lizenz <a class="internal"
#                         href="https://de.wikipedia.org/wiki/Wikipedia:Lizenzbestimmungen_Creative_Commons_Attribution-ShareAlike_3.0_Unported">„Creative
#                         Commons Attribution/Share Alike“</a> verfügbar; Informationen zu den Urhebern und zum
#                     Lizenzstatus eingebundener Mediendateien (etwa Bilder oder Videos) können im Regelfall durch
#                     Anklicken dieser abgerufen werden. Möglicherweise unterliegen die Inhalte jeweils zusätzlichen
#                     Bedingungen. Durch die Nutzung dieser Website erklären Sie sich mit den <a class="internal"
#                         href="https://foundation.wikimedia.org/wiki/Terms_of_Use/de">Nutzungsbedingungen</a> und der <a
#                         class="internal"
#                         href="https://meta.wikimedia.org/wiki/Privacy_policy/de">Datenschutzrichtlinie</a>
#                     einverstanden.<br />
#                     Wikipedia® ist eine eingetragene Marke der Wikimedia Foundation Inc.</div>
#             </li>
#         </ul>
#
#         <ul id="footer-places">
#             <li id="footer-places-privacy"><a href="https://meta.wikimedia.org/wiki/Privacy_policy/de">Datenschutz</a>
#             </li>
#             <li id="footer-places-about"><a href="/wiki/Wikipedia:%C3%9Cber_Wikipedia">Über Wikipedia</a></li>
#             <li id="footer-places-disclaimers"><a href="/wiki/Wikipedia:Impressum">Impressum</a></li>
#             <li id="footer-places-mobileview"><a
#                     href="//de.m.wikipedia.org/w/index.php?title=Wikipedia:Exzellente_Artikel&amp;mobileaction=toggle_view_mobile"
#                     class="noprint stopMobileRedirectToggle">Mobile Ansicht</a></li>
#             <li id="footer-places-developers"><a href="https://developer.wikimedia.org">Entwickler</a></li>
#             <li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/de.wikipedia.org">Statistiken</a>
#             </li>
#             <li id="footer-places-cookiestatement"><a
#                     href="https://foundation.wikimedia.org/wiki/Cookie_statement">Stellungnahme zu Cookies</a></li>
#         </ul>
#
#         <ul id="footer-icons" class="noprint">
#             <li id="footer-copyrightico"><a href="https://wikimediafoundation.org/"><img
#                         src="/static/images/footer/wikimedia-button.png"
#                         srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x"
#                         width="88" height="31" alt="Wikimedia Foundation" loading="lazy" /></a></li>
#             <li id="footer-poweredbyico"><a href="https://www.mediawiki.org/"><img
#                         src="/static/images/footer/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki"
#                         srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x"
#                         width="88" height="31" loading="lazy" /></a></li>
#         </ul>
#
#     </footer>
#
#     <script>(RLQ = window.RLQ || []).push(function () { mw.config.set({ "wgHostname": "mw1417", "wgBackendResponseTime": 99, "wgDiscussionToolsPageThreads": [{ "headingLevel": 3, "name": "h-", "type": "heading", "level": 0, "id": "h-Geographie", "replies": [] }, { "headingLevel": 3, "name": "h-", "type": "heading", "level": 0, "id": "h-Geschichte", "replies": [] }, { "headingLevel": 3, "name": "h-", "type": "heading", "level": 0, "id": "h-Gesellschaft", "replies": [] }, { "headingLevel": 3, "name": "h-", "type": "heading", "level": 0, "id": "h-Kunst_und_Kultur", "replies": [] }, { "headingLevel": 3, "name": "h-", "type": "heading", "level": 0, "id": "h-Religion", "replies": [] }, { "headingLevel": 3, "name": "h-", "type": "heading", "level": 0, "id": "h-Sport", "replies": [] }, { "headingLevel": 3, "name": "h-", "type": "heading", "level": 0, "id": "h-Technik_und_Verkehr", "replies": [] }, { "headingLevel": 3, "name": "h-", "type": "heading", "level": 0, "id": "h-Wissenschaft_und_Philosophie", "replies": [] }], "wgPageParseReport": { "discussiontools": { "limitreport-timeusage": "0.174" }, "limitreport": { "cputime": "0.980", "walltime": "1.168", "ppvisitednodes": { "value": 1514, "limit": 1000000 }, "postexpandincludesize": { "value": 408120, "limit": 2097152 }, "templateargumentsize": { "value": 279229, "limit": 2097152 }, "expansiondepth": { "value": 15, "limit": 100 }, "expensivefunctioncount": { "value": 2, "limit": 500 }, "unstrip-depth": { "value": 0, "limit": 20 }, "unstrip-size": { "value": 14269, "limit": 5000000 }, "entityaccesscount": { "value": 0, "limit": 400 }, "timingprofile": ["100.00%  276.392      1 -total", " 50.39%  139.269      8 Wikipedia:Exzellente_Artikel/Themenpanel", " 13.58%   37.533      1 Wikipedia:Exzellente_Artikel/Wissenschaft", " 12.05%   33.302      1 Vorlage:Shortcut", " 10.57%   29.203      1 Vorlage:Index-Nachschlagen", " 10.26%   28.359      1 Wikipedia:Exzellente_Artikel/Geographie", "  9.58%   26.473      1 Vorlage:Subpage", "  9.17%   25.337      1 Wikipedia:Exzellente_Artikel/Kunst_und_Kultur", "  8.90%   24.595      1 Wikipedia:Exzellente_Artikel/Geschichte", "  8.90%   24.591      1 Wikipedia:Exzellente_Artikel/Intro"] }, "scribunto": { "limitreport-timeusage": { "value": "0.014", "limit": "10.000" }, "limitreport-memusage": { "value": 1148113, "limit": 52428800 } }, "cachereport": { "origin": "mw1374", "timestamp": "20230502162423", "ttl": 1814400, "transientcontent": false } } }); });</script>
# </body>
#
# </html>
# {'Gewässer': 35, 'Landschaften und Natursehenswürdigkeiten': 70, 'Staaten': 9, 'Regionen': 16, 'Inseln': 3, ' Städte in Deutschland, Österreich und der Schweiz': 57, 'Städte (weltweit)': 29, 'Stadtteile': 11, 'Ländliche Gemeinden': 33, 'Straßen, Plätze und Parkanlagen': 18, 'Ortsteile': 7, 'Geschichte einzelner Regionen': 22, 'Ur- und Frühgeschichte, Ägyptologie und Altorientalistik': 44, 'Antike': 85, 'Frühzeit außerhalb Europas und Vorderasiens': 4, 'Mittelalter': 62, 'Frühe Neuzeit': 54, '19. Jahrhundert': 74, '1900–1933': 50, '1933–1945': 68, '1945 bis heute': 37, 'Militärgeschichte': 3, 'Sonstige': 3, 'Politik': 26, 'Recht': 26, 'Militär': 4, 'Wirtschaft': 19, 'Bildungseinrichtungen': 6, 'Gesundheitswesen': 4, 'Dinge des Alltags': 5, 'Essen, Trinken und Genießen': 11, 'Heraldik und Vexillologie': 9, 'Karitatives': 5, 'Kriminalität': 2, 'Massenmedien': 4, 'Ritual': 3, 'Emotionen': 1, 'Sexualität': 1, 'Spiele': 18, 'Verschwörungstheorien': 1, 'Volkskunde und Brauchtum': 2, 'Wohnungsbau': 1, 'Frauenwahlrecht': 1, 'Übersichtsartikel': 4, 'Bildende Kunst/Allgemeines': 17, 'Bildende Kunst/Künstler': 39, 'Bildende Kunst/Werke': 43, 'Architektur/Allgemeines': 11, 'Burgen, Festungen und Schlösser': 39, 'Einzelne Sakralbauten': 49, 'Brücken, Tunnel und Türme': 24, 'Sonstige Einzelbauten': 46, 'Friedhöfe': 7, 'Literatur und Theater/Autoren': 41, 'Literatur und Theater/Werke u. a.': 61, 'Aufführungshäuser für Tanz, Theater und Musik': 7, 'Sprache und Schrift': 24, 'Musik/Allgemeines': 37, 'Musik/Künstler': 47, 'Musik/Werke': 38, 'Fotografie': 2, 'Radio, Film und Fernsehen': 59, 'Christentum': 14, 'Christliche Persönlichkeiten': 12, 'Judentum': 5, 'Islam': 7, 'Weitere Religionen': 5, 'Olympische Spiele': 17, 'Fußball': 26, 'Motorsport': 11, 'Tennis': 2, 'Wintersport': 16, 'Andere Sportartikel': 20, 'Bahn': 18, 'Bahnstrecken und -netze': 33, 'U-Bahn': 14, 'Straßenbahn': 25, 'Luftfahrt': 23, 'Raumfahrt': 15, 'Kraftfahrzeuge': 16, 'Computer und Videospielkonsolen': 24, 'Mess- und Energietechnik': 4, 'Informations- und Kommunikationstechnik': 12, 'Waffentechnik': 20, 'Werkstoffe': 3, 'Maschinenbau': 2, 'Elektrotechnik': 2, 'Verfahrenstechnik': 4, 'Wissenschaftler': 55, 'Biologische Grundbegriffe': 6, 'Entwicklungsbiologie und Evolutionsbiologie': 6, 'Forschungseinrichtungen': 1, 'Anatomie und Physiologie': 22, 'Allgemeine Ökologie, Landschaftsökologie': 13, 'Verhaltensbiologie': 2, 'Systematik': 2, 'Viren, Bakterien, Einzeller': 8, 'Pilze': 4, ' Pflanzen': 66, ' Wirbellose Tiere': 70, 'Säugetiere': 90, 'Vögel': 81, 'Knorpel- und Knochenfische': 8, 'Amphibien': 6, 'Reptilien': 20, 'Biochemie': 8, 'Genetik und Molekularbiologie': 6, 'Paläontologie': 34, 'Astronomie': 25, 'Chemie': 54, 'Metallurgie': 1, 'Geowissenschaften und Mineralogie': 20, 'Klimatologie': 6, 'Informatik': 10, 'Mathematik': 21, 'Medizin und Mikrobiologie': 63, 'Zahnmedizin': 5, 'Tiermedizin': 22, 'Pharmazie': 6, 'Physik': 14, 'Philosophie': 90, 'Soziologie': 4, 'Ethnologie': 26, 'Ethnologen': 4, 'Psychologie': 5, 'Psychiatrie': 1, 'Pädagogik': 2, 'Wirtschaftswissenschaft': 12}

# %%
# Assuming the function count_elements is already defined

# Replace 'your_html_file.html' with the path to your HTML file
with open('data/data_files/data_insights/readworthy_html_full.html', 'r', encoding='utf-8') as file:
    html_content = file.read()

readworthy_cats,readworthy_topics = count_items(html_content)
for key in drop_dict_list:
    readworthy_topics.pop(key, None)

print(readworthy_topics)
# Out:
# {'Geographie': 436, 'Geschichte': 702, 'Gesellschaft': 477, 'Kunst und Kultur': 899, 'Religion': 107, 'Sport': 264, 'Technik und Verkehr': 505, 'Wissenschaft und Philosophie': 1018}

# %%
# Convert the dictionaries to pandas DataFrames
read_df = pd.DataFrame(list(readworthy_topics.items()), columns=['Topic', 'Value'])
read_df['Source'] = 'Dict 1'
exc_df = pd.DataFrame(list(excellent_topics.items()), columns=['Topic', 'Value'])
exc_df['Source'] = 'Dict 2'

# Calculate the total count for each dataframe
total_count_read = read_df['Value'].sum()
total_count_exc = exc_df['Value'].sum()

# Calculate the shares of the total for each dataframe
read_df['share'] = read_df['Value'] / total_count_read
exc_df['share'] = exc_df['Value'] / total_count_exc

# Add a 'source' column to identify the dataframes
exc_df['Origin'] = 'Excellent'
read_df['Origin'] = 'Readworthy'

# Concatenate the dataframes
combined_df = pd.concat([ exc_df,read_df], axis=0)

sorting_order = read_df.sort_values('share',ascending=False)['Topic'].tolist()
current_palette = sns.color_palette()
custom_palette = [current_palette[1], current_palette[2]]
# Create a seaborn barplot
sns.barplot(data=combined_df, x='Topic', y='share', hue='Origin',order = sorting_order,palette=custom_palette)

# Rotate x-axis labels
plt.xticks(rotation=80)
plt.title('Qualitative origins grouped by Topic')
# Set axis labels
plt.xlabel('Topics')
plt.ylabel('Share')

# Show the plot
plt.show()

# %%
print(readworthy_topics.keys())
# Out:
# dict_keys(['Geographie', 'Geschichte', 'Gesellschaft', 'Kunst und Kultur', 'Religion', 'Sport', 'Technik und Verkehr', 'Wissenschaft und Philosophie'])

# %%
print(split_text[16])
# Out:
#  Städte in Deutschland, Österreich und der Schweiz:</b>
# <a href="/wiki/Aarau" title="Aarau">Aarau</a> ·
#                                                         <a href="/wiki/Apolda" title="Apolda">Apolda</a> ·
#                                                         <a href="/wiki/Arbon" title="Arbon">Arbon</a> ·
#                                                         <span class="noprint noviewer"><span aria-hidden="true" role="presentation"><a class="image" href="/wiki/Datei:Loudspeaker.svg" title="Gesprochener Inhalt"><img alt="" data-file-height="20" data-file-width="20" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Loudspeaker.svg/12px-Loudspeaker.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Loudspeaker.svg/18px-Loudspeaker.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Loudspeaker.svg/24px-Loudspeaker.svg.png 2x" width="12"/></a></span></span> <a href="/wiki/Augsburg" title="Augsburg">Augsburg</a> ·
#                                                         <a href="/wiki/Baden_AG" title="Baden AG">Baden AG</a> ·
#                                                         <a href="/wiki/Bielefeld" title="Bielefeld">Bielefeld</a> ·
#                                                         <a href="/wiki/Bonn" title="Bonn">Bonn</a> ·
#                                                         <a href="/wiki/Braunschweig" title="Braunschweig">Braunschweig</a> ·
#                                                         <a href="/wiki/Bremgarten_AG" title="Bremgarten AG">Bremgarten
#                                                             AG</a> ·
#                                                         <a href="/wiki/Brugg" title="Brugg">Brugg</a> ·
#                                                         <a href="/wiki/Delitzsch" title="Delitzsch">Delitzsch</a> ·
#                                                         <span class="noprint noviewer"><span aria-hidden="true" role="presentation"><a class="image" href="/wiki/Datei:Loudspeaker.svg" title="Gesprochener Inhalt"><img alt="" data-file-height="20" data-file-width="20" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Loudspeaker.svg/12px-Loudspeaker.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Loudspeaker.svg/18px-Loudspeaker.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Loudspeaker.svg/24px-Loudspeaker.svg.png 2x" width="12"/></a></span></span> <a href="/wiki/Dresden" title="Dresden">Dresden</a> ·
#                                                         <a href="/wiki/Eberswalde" title="Eberswalde">Eberswalde</a> ·
#                                                         <a href="/wiki/Elsterwerda" title="Elsterwerda">Elsterwerda</a>
#                                                         ·
#                                                         <a href="/wiki/Emden" title="Emden">Emden</a> ·
#                                                         <a href="/wiki/Erkelenz" title="Erkelenz">Erkelenz</a> ·
#                                                         <a href="/wiki/Erkrath" title="Erkrath">Erkrath</a> ·
#                                                         <a href="/wiki/Frankfurt_am_Main" title="Frankfurt am Main">Frankfurt am Main</a> ·
#                                                         <a href="/wiki/Freiburg_im_%C3%9Cechtland" title="Freiburg im Üechtland">Freiburg im Üechtland</a> ·
#                                                         <a href="/wiki/Freistadt" title="Freistadt">Freistadt</a> ·
#                                                         <a href="/wiki/Freudenstadt" title="Freudenstadt">Freudenstadt</a> ·
#                                                         <a href="/wiki/Sch%C3%BCttorf" title="Schüttorf">Schüttorf</a> ·
#                                                         <a href="/wiki/Senftenberg" title="Senftenberg">Senftenberg</a>
#                                                         ·
#                                                         <a href="/wiki/Teltow" title="Teltow">Teltow</a> ·
#                                                         <a href="/wiki/Weinsberg" title="Weinsberg">Weinsberg</a> ·
#                                                         <a href="/wiki/Wetzlar" title="Wetzlar">Wetzlar</a> ·
#                                                         <a href="/wiki/Wiesbaden" title="Wiesbaden">Wiesbaden</a> ·
#                                                         <a href="/wiki/Wiesmoor" title="Wiesmoor">Wiesmoor</a> ·
#                                                         <a href="/wiki/Wittmund" title="Wittmund">Wittmund</a> ·
#                                                         <a href="/wiki/Xanten" title="Xanten">Xanten</a> ·
#                                                         <a href="/wiki/Zofingen" title="Zofingen">Zofingen</a>
# </p>
# <div class="floatright">
# <div class="noresize"><a href="/wiki/Toronto" title="Toronto(→ zum Artikel)"><img alt="Skyline von Toronto" data-file-height="2808" data-file-width="4006" decoding="async" height="84" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Toronto_-_ON_-_Skyline_bei_Nacht.jpg/120px-Toronto_-_ON_-_Skyline_bei_Nacht.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Toronto_-_ON_-_Skyline_bei_Nacht.jpg/180px-Toronto_-_ON_-_Skyline_bei_Nacht.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Toronto_-_ON_-_Skyline_bei_Nacht.jpg/240px-Toronto_-_ON_-_Skyline_bei_Nacht.jpg 2x" width="120"/></a></div>
# </div>

# %%
# Out:
# {'Gewässer:\nAlmsee ·\n                                                        Altausseer\n                                                            See ·\n                                                         Amper ·\n                                                        Bäke\n                                                            (Telte) ·\n                                                        Blabbergraben ·\n                                                        Bullengraben ·\n                                                        Dornbirner\n                                                            Ach ·\n                                                        Elbe ·\n                                                         Elsterwerda-Grödel-Floßkanal\n                                                        ·\n                                                        Europäisches Nordmeer ·\n                                                        Große Dhünntalsperre ·\n                                                        Grundlsee ·\n                                                         Hochwasser in Würzburg ·\n                                                        Hochwasserrückhaltebecken\n                                                            Jonenbach ·\n                                                        Hochwasserschutz in\n                                                            Dresden ·\n                                                         Isar ·\n                                                         Ludwig-Donau-Main-Kanal\n                                                        ·\n                                                        Main ·\n                                                        Moälven ·\n                                                        Mono Lake ·\n                                                        Nationalpark\n                                                            Schleswig-Holsteinisches Wattenmeer ·\n                                                        Oderteich ·\n                                                        Osterseen ·\n                                                        Parsteiner\n                                                            See ·\n                                                         Pegel Würzburg ·\n                                                        Ragöse ·\n                                                        Schermützelsee ·\n                                                        Thermalbäder Baden ·\n                                                        Toplitzsee ·\n                                                         Walchensee ·\n                                                        Wedeler Au ·\n                                                        Weser ·\n                                                        Wiener Neustädter Kanal\n                                                        ·\n                                                        Wiese\n                                                            (Fluss)\n': 41, 'Landschaften und Natursehenswürdigkeiten:\n Babisnauer Pappel ·\n                                                        Belziger\n                                                            Landschaftswiesen ·\n                                                        Binghöhle ·\n                                                        Bryce-Canyon-Nationalpark\n                                                        ·\n                                                        Büyükkale ·\n                                                        Charlottenhöhle ·\n                                                        Dachsteingebirge ·\n                                                        Drei Zinnen\n                                                        ·\n                                                        Eberstadter\ ...

# %%
# Out:
# {'categories': 0, 'topics': 16547}
